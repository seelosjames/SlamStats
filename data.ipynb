# %%
import pandas as pd
from datetime import datetime

# %%
def createDummyData():
    teams = [
        {'TeamID': 0, 'Name': 'Utah State', 'Conference': 'Mountain West', 'City': 'Logan', 'State': 'Utah'},
        {'TeamID': 1, 'Name': 'Boise State', 'Conference': 'Mountain West', 'City': 'Boise', 'State': 'Idaho'},
    ]

    players = [
        {'PlayerID': 0, 'Name': 'Isabella Rivera', 'Team': 1, 'City': 'Las Vegas', 'State': 'Nevada', 'Country': 'United States', 'RecruitingRank': 16, 'Class': 'Freshman'},
        {'PlayerID': 1, 'Name': 'John Doe', 'Team': 1, 'City': 'New York City', 'State': 'New York', 'Country': 'United States', 'RecruitingRank': 5, 'Class': 'Senior'},
        {'PlayerID': 2, 'Name': 'Jane Smith', 'Team': 1, 'City': 'Los Angeles', 'State': 'California', 'Country': 'United States', 'RecruitingRank': 8, 'Class': 'Junior'},
        {'PlayerID': 3, 'Name': 'Bob Johnson', 'Team': 1, 'City': 'Chicago', 'State': 'Ilinois', 'Country': 'United States', 'RecruitingRank': 12, 'Class': 'Sophomore'},
        {'PlayerID': 4, 'Name': 'Alice Brown', 'Team': 1, 'City': 'Miami', 'State': 'Florida', 'Country': 'United States', 'RecruitingRank': 15, 'Class': 'Freshman'},
        {'PlayerID': 5, 'Name': 'Charlie White', 'Team': 1, 'City': 'San Francisco', 'State': 'California', 'Country': 'United States', 'RecruitingRank': 9, 'Class': 'Senior'},
        {'PlayerID': 6, 'Name': 'Emma Davis', 'Team': 1, 'City': 'Seattle', 'State': 'Washington', 'Country': 'United States', 'RecruitingRank': 7, 'Class': 'Junior'},
        {'PlayerID': 7, 'Name': 'David Lee', 'Team': 1, 'City': 'Dallas', 'State': 'Texas', 'Country': 'United States', 'RecruitingRank': 11, 'Class': 'Sophomore'},
        {'PlayerID': 8, 'Name': 'Grace Miller', 'Team': 1, 'City': 'Denver', 'State': 'Colorado', 'Country': 'United States', 'RecruitingRank': 14, 'Class': 'Freshman'},
        {'PlayerID': 9, 'Name': 'Ethan Wilson', 'Team': 1, 'City': 'Phoenix', 'State': 'Arizona', 'Country': 'United States', 'RecruitingRank': 6, 'Class': 'Senior'},
        {'PlayerID': 10, 'Name': 'Olivia Clark', 'Team': 0, 'City': 'Atlanta', 'State': 'Georgia', 'Country': 'United States', 'RecruitingRank': 10, 'Class': 'Junior'},
        {'PlayerID': 11, 'Name': 'Frank Martinez', 'Team': 0, 'City': 'Houston', 'State': 'Texas', 'Country': 'United States', 'RecruitingRank': 13, 'Class': 'Sophomore'},
        {'PlayerID': 12, 'Name': 'Sophia Johnson', 'Team': 0, 'City': 'Philadelphia', 'State': 'Pennsylvania', 'Country': 'United States', 'RecruitingRank': 18, 'Class': 'Freshman'},
        {'PlayerID': 13, 'Name': 'Gary Wilson', 'Team': 0, 'City': 'Detroit', 'State': 'Michigain', 'Country': 'United States', 'RecruitingRank': 21, 'Class': 'Senior'},
        {'PlayerID': 14, 'Name': 'Mia Anderson', 'Team': 0, 'City': 'Minneapolis', 'State': 'Minnesota', 'Country': 'United States', 'RecruitingRank': 24, 'Class': 'Junior'},
        {'PlayerID': 15, 'Name': 'Hank Garcia', 'Team': 0, 'City': 'San Diego', 'State': 'California', 'Country': 'United States', 'RecruitingRank': 17, 'Class': 'Sophomore'},
        {'PlayerID': 16, 'Name': 'Lily Martin', 'Team': 0, 'City': 'Portland', 'State': 'Oregon', 'Country': 'United States', 'RecruitingRank': 20, 'Class': 'Freshman'},
        {'PlayerID': 17, 'Name': 'Samuel Taylor', 'Team': 0, 'City': 'Charlotte', 'State': 'North Carolina', 'Country': 'United States', 'RecruitingRank': 23, 'Class': 'Senior'},
        {'PlayerID': 18, 'Name': 'Ava Perez', 'Team': 0, 'City': 'New Orleans', 'State': 'Louisiana', 'Country': 'United States', 'RecruitingRank': 19, 'Class': 'Junior'},
        {'PlayerID': 19, 'Name': 'Daniel Scott', 'Team': 0, 'City': 'Salt Lake City', 'State': 'Uah', 'Country': 'United States', 'RecruitingRank': 22, 'Class': 'Sophomore'},
    ]

    matchups = [
        {'MatchupID': 0, 'HomeTeam': 0, 'HomeTeamRanking': None, 'HomeTeamBoxScore': 0, 'AwayTeam': 1, 'AwayTeamRanking': 22, 'AwayTeamBoxScore': 1, 'MatchupURL': 'google.com', 'Neutral': False}
    ]

    box_scores = [
        {'BoxScoreID': 0, 'MatchupID': 0, 'Home': True},
        {'BoxScoreID': 1, 'MatchupID': 0, 'Home': False}
    ]

    player_stats = [
        {'BoxScoreID': 0, 'PlayerID': 0, 'MinPlayed': 29, 'FG': 6, 'FGA': 13, 'TwoPoint': 5, 'TwoPointA': 9, 'ThreePoint': 1, 'ThreePointA': 4, 'FT': 3, 'FTA': 4, 'ORB': 2, 'DRB': 3, 'A': 4, 'PF': 2, 'STL': 2, 'TO': 1, 'BLK': 0, 'PTS': 16},
        {'BoxScoreID': 0, 'PlayerID': 1, 'MinPlayed': 32, 'FG': 7, 'FGA': 15, 'TwoPoint': 6, 'TwoPointA': 10, 'ThreePoint': 1, 'ThreePointA': 5, 'FT': 3, 'FTA': 4, 'ORB': 2, 'DRB': 5, 'A': 4, 'PF': 3, 'STL': 2, 'TO': 1, 'BLK': 1, 'PTS': 18},
        {'BoxScoreID': 0, 'PlayerID': 2, 'MinPlayed': 28, 'FG': 5, 'FGA': 12, 'TwoPoint': 4, 'TwoPointA': 9, 'ThreePoint': 1, 'ThreePointA': 3, 'FT': 2, 'FTA': 2, 'ORB': 1, 'DRB': 4, 'A': 6, 'PF': 2, 'STL': 3, 'TO': 2, 'BLK': 0, 'PTS': 13},
        {'BoxScoreID': 0, 'PlayerID': 3, 'MinPlayed': 25, 'FG': 8, 'FGA': 18, 'TwoPoint': 7, 'TwoPointA': 12, 'ThreePoint': 1, 'ThreePointA': 6, 'FT': 2, 'FTA': 3, 'ORB': 3, 'DRB': 6, 'A': 3, 'PF': 4, 'STL': 1, 'TO': 3, 'BLK': 2, 'PTS': 19},
        {'BoxScoreID': 0, 'PlayerID': 4, 'MinPlayed': 30, 'FG': 6, 'FGA': 14, 'TwoPoint': 5, 'TwoPointA': 10, 'ThreePoint': 1, 'ThreePointA': 4, 'FT': 2, 'FTA': 3, 'ORB': 2, 'DRB': 3, 'A': 5, 'PF': 3, 'STL': 1, 'TO': 2, 'BLK': 1, 'PTS': 15},
        {'BoxScoreID': 0, 'PlayerID': 5, 'MinPlayed': 33, 'FG': 9, 'FGA': 16, 'TwoPoint': 8, 'TwoPointA': 12, 'ThreePoint': 1, 'ThreePointA': 4, 'FT': 4, 'FTA': 5, 'ORB': 1, 'DRB': 6, 'A': 3, 'PF': 2, 'STL': 2, 'TO': 2, 'BLK': 1, 'PTS': 23},
        {'BoxScoreID': 0, 'PlayerID': 6, 'MinPlayed': 27, 'FG': 4, 'FGA': 11, 'TwoPoint': 3, 'TwoPointA': 7, 'ThreePoint': 1, 'ThreePointA': 4, 'FT': 3, 'FTA': 3, 'ORB': 0, 'DRB': 5, 'A': 4, 'PF': 2, 'STL': 3, 'TO': 1, 'BLK': 0, 'PTS': 12},
        {'BoxScoreID': 0, 'PlayerID': 7, 'MinPlayed': 29, 'FG': 6, 'FGA': 13, 'TwoPoint': 5, 'TwoPointA': 10, 'ThreePoint': 1, 'ThreePointA': 3, 'FT': 4, 'FTA': 5, 'ORB': 2, 'DRB': 4, 'A': 6, 'PF': 3, 'STL': 2, 'TO': 3, 'BLK': 1, 'PTS': 17},
        {'BoxScoreID': 0, 'PlayerID': 8, 'MinPlayed': 31, 'FG': 5, 'FGA': 14, 'TwoPoint': 4, 'TwoPointA': 8, 'ThreePoint': 1, 'ThreePointA': 6, 'FT': 4, 'FTA': 5, 'ORB': 3, 'DRB': 7, 'A': 2, 'PF': 2, 'STL': 1, 'TO': 2, 'BLK': 2, 'PTS': 15},
        {'BoxScoreID': 0, 'PlayerID': 9, 'MinPlayed': 30, 'FG': 8, 'FGA': 17, 'TwoPoint': 7, 'TwoPointA': 11, 'ThreePoint': 1, 'ThreePointA': 6, 'FT': 3, 'FTA': 4, 'ORB': 1, 'DRB': 6, 'A': 5, 'PF': 3, 'STL': 3, 'TO': 2, 'BLK': 1, 'PTS': 20},
        {'BoxScoreID': 1, 'PlayerID': 10, 'MinPlayed': 28, 'FG': 6, 'FGA': 13, 'TwoPoint': 5, 'TwoPointA': 10, 'ThreePoint': 1, 'ThreePointA': 3, 'FT': 3, 'FTA': 4, 'ORB': 2, 'DRB': 3, 'A': 4, 'PF': 2, 'STL': 2, 'TO': 1, 'BLK': 0, 'PTS': 16},
        {'BoxScoreID': 1, 'PlayerID': 11, 'MinPlayed': 26, 'FG': 7, 'FGA': 16, 'TwoPoint': 6, 'TwoPointA': 11, 'ThreePoint': 1, 'ThreePointA': 5, 'FT': 2, 'FTA': 3, 'ORB': 1, 'DRB': 4, 'A': 3, 'PF': 4, 'STL': 1, 'TO': 2, 'BLK': 1, 'PTS': 17},
        {'BoxScoreID': 1, 'PlayerID': 12, 'MinPlayed': 24, 'FG': 4, 'FGA': 9, 'TwoPoint': 3, 'TwoPointA': 7, 'ThreePoint': 1, 'ThreePointA': 2, 'FT': 3, 'FTA': 4, 'ORB': 0, 'DRB': 3, 'A': 2, 'PF': 3, 'STL': 1, 'TO': 1, 'BLK': 0, 'PTS': 12},
        {'BoxScoreID': 1, 'PlayerID': 13, 'MinPlayed': 33, 'FG': 9, 'FGA': 19, 'TwoPoint': 8, 'TwoPointA': 13, 'ThreePoint': 1, 'ThreePointA': 6, 'FT': 2, 'FTA': 3, 'ORB': 3, 'DRB': 7, 'A': 5, 'PF': 2, 'STL': 3, 'TO': 2, 'BLK': 1, 'PTS': 21},
        {'BoxScoreID': 1, 'PlayerID': 14, 'MinPlayed': 28, 'FG': 5, 'FGA': 12, 'TwoPoint': 4, 'TwoPointA': 8, 'ThreePoint': 1, 'ThreePointA': 4, 'FT': 2, 'FTA': 2, 'ORB': 2, 'DRB': 4, 'A': 3, 'PF': 3, 'STL': 1, 'TO': 1, 'BLK': 0, 'PTS': 13},
        {'BoxScoreID': 1, 'PlayerID': 15, 'MinPlayed': 31, 'FG': 8, 'FGA': 16, 'TwoPoint': 7, 'TwoPointA': 12, 'ThreePoint': 1, 'ThreePointA': 4, 'FT': 4, 'FTA': 5, 'ORB': 1, 'DRB': 6, 'A': 3, 'PF': 2, 'STL': 2, 'TO': 2, 'BLK': 1, 'PTS': 21},
        {'BoxScoreID': 1, 'PlayerID': 16, 'MinPlayed': 26, 'FG': 4, 'FGA': 11, 'TwoPoint': 3, 'TwoPointA': 8, 'ThreePoint': 1, 'ThreePointA': 3, 'FT': 2, 'FTA': 2, 'ORB': 1, 'DRB': 4, 'A': 2, 'PF': 2, 'STL': 3, 'TO': 1, 'BLK': 0, 'PTS': 11},
        {'BoxScoreID': 1, 'PlayerID': 17, 'MinPlayed': 30, 'FG': 7, 'FGA': 15, 'TwoPoint': 6, 'TwoPointA': 11, 'ThreePoint': 1, 'ThreePointA': 4, 'FT': 3, 'FTA': 4, 'ORB': 2, 'DRB': 5, 'A': 4, 'PF': 3, 'STL': 1, 'TO': 2, 'BLK': 1, 'PTS': 18},
        {'BoxScoreID': 1, 'PlayerID': 18, 'MinPlayed': 28, 'FG': 5, 'FGA': 12, 'TwoPoint': 4, 'TwoPointA': 9, 'ThreePoint': 1, 'ThreePointA': 3, 'FT': 2, 'FTA': 2, 'ORB': 1, 'DRB': 4, 'A': 6, 'PF': 2, 'STL': 3, 'TO': 2, 'BLK': 0, 'PTS': 13},
        {'BoxScoreID': 1, 'PlayerID': 19, 'MinPlayed': 25, 'FG': 8, 'FGA': 17, 'TwoPoint': 7, 'TwoPointA': 11, 'ThreePoint': 1, 'ThreePointA': 6, 'FT': 3, 'FTA': 4, 'ORB': 1, 'DRB': 6, 'A': 5, 'PF': 3, 'STL': 3, 'TO': 2, 'BLK': 1, 'PTS': 20},
    ]

    settings = [
        {'MatchupID': 0, 'Date': datetime(2023, 12, 14, 15, 0, 0), 'City': 'Logan', 'State': 'Utah', 'Country': 'United States', 'Arena': 'Dee Glen Smith Spectrum', 'Attendance': 10000}
    ]

    scoring = [
        {'MatchupID': 0, 'HomeFirst': 70, 'HomeSecond': 80, 'HomeOT1': 18, 'HomeOT2': None, 'HomeOT3': None, 'HomeTotal': 168, 'AwayFirst': 62, 'AwaySecond': 80, 'AwayOT1': 22, 'AwayOT2': None, 'AwayOT3': None, 'AwayTotal': 162}
    ]

    teams_df = pd.DataFrame(teams)
    players_df = pd.DataFrame(players)
    matchups_df = pd.DataFrame(matchups)
    box_scores_df = pd.DataFrame(box_scores)
    player_stats_df = pd.DataFrame(player_stats)
    settings_df = pd.DataFrame(settings)
    scoring = pd.DataFrame(scoring)

# %%
# Save the DataFrame to a CSV file
# teams_df.to_csv('test_data/teams.csv', index=False)
# players_df.to_csv('test_data/players.csv', index=False)
# matchups_df.to_csv('test_data/matchups.csv', index=False)
# box_scores_df.to_csv('test_data/box_scores.csv', index=False)
# player_stats_df.to_csv('test_data/player_stats.csv', index=False)
# settings_df.to_csv('test_data/settings.csv', index=False)
# scoring.to_csv('test_data/scoring.csv', index=False)

# %%
def fillData():
    for year in range(2010, 2023):
        print("" + str(year) + "-" + str(year + 1) + ".csv")
        df_box = pd.read_csv("data/box_scores/" + str(year) + "-" + str(year + 1) + ".csv")
        df_matchup = pd.read_csv("data/matchups/" + str(year) + "-" + str(year + 1) + ".csv")
        na_index = df_matchup[df_matchup['box_score_url'] == 'na'].index

        missing_data = {
                'game_time': 'na',
                'arena': 'na',
                'city': 'na',
                'state': 'na',
                'attendance': 'na',
                'away_1': 'na',
                'away_2': 'na',
                'away_ot': 'na',
                'away_ot2': 'na',
                'away_ot3': 'na',
                'away_tot': 'na',
                'home_1': 'na',
                'home_2': 'na',
                'home_ot': 'na',
                'home_ot2': 'na',
                'home_ot3': 'na',
                'home_tot': 'na',
                'away': 'na',
                'home': 'na'
            }
        
        
        for row in na_index:
            df_box = pd.concat([df_box.loc[:row - 1], pd.DataFrame([missing_data]), df_box.loc[row:]]).reset_index(drop=True)
            # print(row)

        df_box.to_csv("testing/" + str(year) + "-" + str(year + 1) + ".csv", index=False)

# %%
def createMatchup(index, box_info, matchup_info):
    matchup = {}

    matchup['matchup_id'] = index
    matchup['home_team'] = matchup_info['home_team']
    matchup['home_team_ranking'] = int(matchup_info['home_team_ranking'])
    matchup['home_team_box'] = index * 2
    matchup['away_team'] = matchup_info['away_team']
    matchup['away_team_ranking'] = int(matchup_info['away_team_ranking'])
    matchup['away_team_box'] = (index * 2) + 1
    matchup['url'] = matchup_info['box_score_url']
    matchup['neutral'] = bool(matchup_info['neutral'])

    return matchup

# %%
def createScoring(index, box_info, matchup_info):
    scoring = {}

    scoring['matchup_id'] = index
    scoring['home_first'] = int(box_info['home_1'])
    scoring['home_second'] = int(box_info['home_2'])
    scoring['home_ot'] =  int(box_info['home_tot']) - (int(box_info['home_1']) + int(box_info['home_2']))
    scoring['home_total'] = int(box_info['home_tot'])
    scoring['away_first'] = int(box_info['home_1'])
    scoring['away_second'] = int(box_info['home_2'])
    scoring['away_ot'] = int(box_info['away_tot']) - (int(box_info['away_1']) + int(box_info['away_2']))
    scoring['away_total'] = int(box_info['away_tot'])

    return scoring

# %%
def createSetting(index, box_info, matchup_info):
    setting = {}
    date_format = "%m/%d/%Y %I:%M %p"

    setting['matchup_id'] = index
    setting['date'] = datetime.strptime(matchup_info['date'] + " " + box_info['game_time'], date_format)
    setting['city'] = box_info['city']
    setting['state'] = box_info['state']
    setting['country'] = ''
    setting['arena'] = box_info['arena']

    if box_info['attendance'] != box_info['attendance']:
        setting['attendance'] = None
    else:
        setting['attendance'] = int(float(box_info['attendance']))

    return setting

# %%
def createBoxScore(index, matchup_id, box_info, matchup_info):
    box_score = {}

    box_score['box_score_id'] = index
    box_score['matchup_id'] = matchup_id
    box_score['home'] = True if index % 2 == 0 else False

    return box_score

# %%
def createPlayerStats(index, box_info, matchup_info):
    player_stats = []
    stats = eval(box_info['away']) if index % 2 == 1 else eval(box_info['home'])
    player_names_list = list(stats.keys())

    for name in player_names_list:
        player_stat = {}
        player_stat['box_score_id'] = index
        player_stat['player_id'] = stats[name]['player_url_id']
        player_stat['minutes_played'] = stats[name]['min_played']
        player_stat['fg'] = stats[name]['fg']
        player_stat['fg_a'] = stats[name]['fg_a']
        player_stat['two_pt'] = stats[name]['two_point']
        player_stat['two_pt_a'] = stats[name]['two_point_a']
        player_stat['three_pt'] = stats[name]['three_point']
        player_stat['three_pt_a'] = stats[name]['three_point_a']
        player_stat['ft'] = stats[name]['ft']
        player_stat['ft_a'] = stats[name]['ft_a']
        player_stat['o_reb'] = stats[name]['orb']
        player_stat['d_reb'] = stats[name]['drb']
        player_stat['assist'] = stats[name]['a']
        player_stat['pf'] = stats[name]['pf']
        player_stat['stl'] = stats[name]['stl']
        player_stat['to'] = stats[name]['to']
        player_stat['blk'] = stats[name]['blk']
        player_stat['pts'] = stats[name]['pts']

        player_stats.append(player_stat)

    return player_stats

# %%
def organize():
    matchups = []
    box_scores = []
    settings = []
    scorings = []
    player_stats = []
    players = []
    teams = []
    for year in range(2010, 2011):

        print("" + str(year) + "-" + str(year + 1) + ".csv")
        df_box = pd.read_csv("data/box_scores/" + str(year) + "-" + str(year + 1) + ".csv").to_dict('records')
        df_matchup = pd.read_csv("data/matchups/" + str(year) + "-" + str(year + 1) + ".csv").to_dict('records')

        for i in range(len(df_matchup)):
            matchups.append(createMatchup(i, df_box[i], df_matchup[i]))

            if df_box[i]['game_time'] != 'na':
                scorings.append(createScoring(i, df_box[i], df_matchup[i]))
                settings.append(createSetting(i, df_box[i], df_matchup[i]))
                box_scores.append(createBoxScore(i * 2, i, df_box[i], df_matchup[i]))
                box_scores.append(createBoxScore((i * 2) + 1, i, df_box[i], df_matchup[i]))
                player_stats = player_stats + createPlayerStats(i * 2, df_box[i], df_matchup)
                player_stats = player_stats + createPlayerStats((i * 2) + 1, df_box[i], df_matchup)
            else:
                scorings.append({'matchup_id': i})
                settings.append({'matchup_id': i})
                box_scores.append({'box_score_id': i * 2, 'matchup_id': i})
                box_scores.append({'box_score_id': (i * 2) + 1, 'matchup_id': i})

            

        # for i in player_stats:
        #     print(i)
    
    return player_stats, box_scores, matchups

# %%
player_stats, box_scores, matchups = organize()
# Out:
# 2010-2011.csv

# %%
for i in range(1000):
    print(player_stats[i])
# Out:
# {'box_score_id': 0, 'player_id': '732784', 'minutes_played': 23, 'fg': 2, 'fg_a': 8, 'two_pt': 1, 'two_pt_a': 5, 'three_pt': 1, 'three_pt_a': 3, 'ft': 5, 'ft_a': 6, 'o_reb': 2, 'd_reb': 4, 'assist': 3, 'pf': 3, 'stl': 2, 'to': 4, 'blk': 1, 'pts': 10}
# {'box_score_id': 0, 'player_id': '744165', 'minutes_played': 20, 'fg': 4, 'fg_a': 6, 'two_pt': 4, 'two_pt_a': 6, 'three_pt': 0, 'three_pt_a': 0, 'ft': 1, 'ft_a': 3, 'o_reb': 4, 'd_reb': 7, 'assist': 0, 'pf': 2, 'stl': 1, 'to': 2, 'blk': 2, 'pts': 9}
# {'box_score_id': 0, 'player_id': '737212', 'minutes_played': 24, 'fg': 2, 'fg_a': 4, 'two_pt': 2, 'two_pt_a': 4, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 2, 'd_reb': 4, 'assist': 0, 'pf': 3, 'stl': 0, 'to': 0, 'blk': 2, 'pts': 4}
# {'box_score_id': 0, 'player_id': '740474', 'minutes_played': 37, 'fg': 8, 'fg_a': 15, 'two_pt': 6, 'two_pt_a': 8, 'three_pt': 2, 'three_pt_a': 7, 'ft': 4, 'ft_a': 5, 'o_reb': 0, 'd_reb': 4, 'assist': 3, 'pf': 1, 'stl': 1, 'to': 2, 'blk': 0, 'pts': 22}
# {'box_score_id': 0, 'player_id': '737213', 'minutes_played': 34, 'fg': 7, 'fg_a': 13, 'two_pt': 7, 'two_pt_a': 12, 'three_pt': 0, 'three_pt_a': 1, 'ft': 10, 'ft_a': 13, 'o_reb': 0, 'd_reb': 3, 'assist': 8, 'pf': 0, 'stl': 1, 'to': 2, 'blk': 0, 'pts': 24}
# {'box_score_id': 0, 'player_id': '744164', 'minutes_played': 24, 'fg': 3, 'fg_a': 9, 'two_pt': 3, 'two_pt_a': 7, 'three_pt': 0, 'three_pt_a': 2, 'ft': 1, 'ft_a': 2, 'o_reb': 1, 'd_reb': 2, 'assist': 3, 'pf': 2, 'stl': 1, 'to': 1, 'blk': 0, 'pts': 7}
# {'box_score_id': 0, 'player_id': '744163', 'minutes_played': 12, 'fg': 1, 'fg_a': 2, 'two_pt': 1, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 2, 'd_reb': 1, 'assist': 1, 'pf': 3, 'stl': 0, 'to': 1, 'blk': 1, 'pts': 2}
# {'box_score_id': 0, 'player_id': '744156', 'minutes_played': 22, 'fg': 2, 'fg_a': 6, 'two_pt': 2, 'two_pt_a': 4, 'three_pt': 0, 'three_pt_a': 2, 'ft': 1, 'ft_a': 1, 'o_reb': 3, 'd_reb': 1, 'assist': 1, 'pf': 4, 'stl': 2, 'to': 2, 'blk': 0, 'pts': 5}
# {'box_score_id': 0, 'player_id': '744158', 'minutes_played': 4, 'fg': 0, 'fg_a': 1, 'two_pt': 0, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 1, 'player_id': '732571', 'minutes_played': 28, 'fg': 6, 'fg_a': 16, 'two_pt': 1, 'two_pt_a': 6, 'three_pt': 5, 'three_pt_a': 10, 'ft': 3, 'ft_a': 4, 'o_reb': 1, 'd_reb': 4, 'assist': 2, 'pf': 3, 'stl': 0, 'to': 2, 'blk': 2, 'pts': 20}
# {'box_score_id': 1, 'player_id': '743984', 'minutes_played': 32, 'fg': 3, 'fg_a': 6, 'two_pt': 3, 'two_pt_a': 6, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 2, 'assist': 1, 'pf': 3, 'stl': 2, 'to': 2, 'blk': 2, 'pts': 6}
# {'box_score_id': 1, 'player_id': '737358', 'minutes_played': 18, 'fg': 2, 'fg_a': 7, 'two_pt': 2, 'two_pt_a': 7, 'three_pt': 0, 'three_pt_a': 0, 'ft': 4, 'ft_a': 4, 'o_reb': 3, 'd_reb': 3, 'assist': 0, 'pf': 4, 'stl': 0, 'to': 0, 'blk': 2, 'pts': 8}
# {'box_score_id': 1, 'player_id': '737357', 'minutes_played': 31, 'fg': 3, 'fg_a': 5, 'two_pt': 2, 'two_pt_a': 2, 'three_pt': 1, 'three_pt_a': 3, 'ft': 1, 'ft_a': 1, 'o_reb': 1, 'd_reb': 5, 'assist': 1, 'pf': 3, 'stl': 1, 'to': 2, 'blk': 0, 'pts': 8}
# {'box_score_id': 1, 'player_id': '743977', 'minutes_played': 31, 'fg': 5, 'fg_a': 13, 'two_pt': 1, 'two_pt_a': 3, 'three_pt': 4, 'three_pt_a': 10, 'ft': 2, 'ft_a': 2, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 2, 'stl': 0, 'to': 2, 'blk': 0, 'pts': 16}
# {'box_score_id': 1, 'player_id': '732757', 'minutes_played': 19, 'fg': 0, 'fg_a': 3, 'two_pt': 0, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 2, 'ft': 0, 'ft_a': 2, 'o_reb': 2, 'd_reb': 3, 'assist': 1, 'pf': 1, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 0}
# {'box_score_id': 1, 'player_id': '747800', 'minutes_played': 1, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 1, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 1, 'player_id': '747802', 'minutes_played': 1, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 1, 'assist': 0, 'pf': 1, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 1, 'player_id': '740023', 'minutes_played': 20, 'fg': 1, 'fg_a': 2, 'two_pt': 1, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 1, 'ft': 2, 'ft_a': 2, 'o_reb': 0, 'd_reb': 1, 'assist': 10, 'pf': 4, 'stl': 3, 'to': 6, 'blk': 0, 'pts': 4}
# {'box_score_id': 1, 'player_id': '743982', 'minutes_played': 13, 'fg': 4, 'fg_a': 8, 'two_pt': 0, 'two_pt_a': 2, 'three_pt': 4, 'three_pt_a': 6, 'ft': 1, 'ft_a': 1, 'o_reb': 0, 'd_reb': 1, 'assist': 0, 'pf': 4, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 13}
# {'box_score_id': 1, 'player_id': '743986', 'minutes_played': 6, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 0, 'assist': 1, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 2, 'player_id': '737161', 'minutes_played': 26, 'fg': 5, 'fg_a': 8, 'two_pt': 5, 'two_pt_a': 8, 'three_pt': 0, 'three_pt_a': 0, 'ft': 1, 'ft_a': 3, 'o_reb': 1, 'd_reb': 7, 'assist': 2, 'pf': 3, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 11}
# {'box_score_id': 2, 'player_id': '737160', 'minutes_played': 20, 'fg': 2, 'fg_a': 4, 'two_pt': 2, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 2, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 4, 'assist': 3, 'pf': 3, 'stl': 0, 'to': 0, 'blk': 1, 'pts': 4}
# {'box_score_id': 2, 'player_id': '737167', 'minutes_played': 27, 'fg': 3, 'fg_a': 6, 'two_pt': 3, 'two_pt_a': 5, 'three_pt': 0, 'three_pt_a': 1, 'ft': 6, 'ft_a': 7, 'o_reb': 4, 'd_reb': 4, 'assist': 1, 'pf': 4, 'stl': 2, 'to': 4, 'blk': 3, 'pts': 12}
# {'box_score_id': 2, 'player_id': '744038', 'minutes_played': 22, 'fg': 3, 'fg_a': 8, 'two_pt': 2, 'two_pt_a': 2, 'three_pt': 1, 'three_pt_a': 6, 'ft': 1, 'ft_a': 2, 'o_reb': 0, 'd_reb': 1, 'assist': 0, 'pf': 2, 'stl': 0, 'to': 2, 'blk': 0, 'pts': 8}
# {'box_score_id': 2, 'player_id': '737163', 'minutes_played': 31, 'fg': 5, 'fg_a': 11, 'two_pt': 4, 'two_pt_a': 6, 'three_pt': 1, 'three_pt_a': 5, 'ft': 2, 'ft_a': 5, 'o_reb': 0, 'd_reb': 4, 'assist': 8, 'pf': 1, 'stl': 3, 'to': 5, 'blk': 1, 'pts': 13}
# {'box_score_id': 2, 'player_id': '744029', 'minutes_played': 4, 'fg': 0, 'fg_a': 2, 'two_pt': 0, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 1, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 1, 'assist': 0, 'pf': 1, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 0}
# {'box_score_id': 2, 'player_id': '744037', 'minutes_played': 21, 'fg': 6, 'fg_a': 8, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 6, 'three_pt_a': 8, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 2, 'assist': 2, 'pf': 1, 'stl': 2, 'to': 0, 'blk': 1, 'pts': 18}
# {'box_score_id': 2, 'player_id': '747421', 'minutes_played': 6, 'fg': 1, 'fg_a': 2, 'two_pt': 1, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 1, 'to': 0, 'blk': 0, 'pts': 2}
# {'box_score_id': 2, 'player_id': '747422', 'minutes_played': 13, 'fg': 1, 'fg_a': 4, 'two_pt': 1, 'two_pt_a': 3, 'three_pt': 0, 'three_pt_a': 1, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 2, 'assist': 0, 'pf': 2, 'stl': 0, 'to': 0, 'blk': 1, 'pts': 2}
# {'box_score_id': 2, 'player_id': '745289', 'minutes_played': 2, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 2, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 2, 'player_id': '747423', 'minutes_played': 17, 'fg': 2, 'fg_a': 3, 'two_pt': 2, 'two_pt_a': 3, 'three_pt': 0, 'three_pt_a': 0, 'ft': 2, 'ft_a': 2, 'o_reb': 1, 'd_reb': 3, 'assist': 1, 'pf': 3, 'stl': 0, 'to': 1, 'blk': 1, 'pts': 6}
# {'box_score_id': 2, 'player_id': '744033', 'minutes_played': 11, 'fg': 1, 'fg_a': 2, 'two_pt': 1, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 0, 'ft': 1, 'ft_a': 2, 'o_reb': 0, 'd_reb': 2, 'assist': 0, 'pf': 2, 'stl': 1, 'to': 0, 'blk': 0, 'pts': 3}
# {'box_score_id': 3, 'player_id': '744250', 'minutes_played': 32, 'fg': 4, 'fg_a': 11, 'two_pt': 3, 'two_pt_a': 6, 'three_pt': 1, 'three_pt_a': 5, 'ft': 2, 'ft_a': 2, 'o_reb': 2, 'd_reb': 2, 'assist': 2, 'pf': 3, 'stl': 1, 'to': 2, 'blk': 0, 'pts': 11}
# {'box_score_id': 3, 'player_id': '740708', 'minutes_played': 33, 'fg': 4, 'fg_a': 10, 'two_pt': 4, 'two_pt_a': 9, 'three_pt': 0, 'three_pt_a': 1, 'ft': 3, 'ft_a': 7, 'o_reb': 5, 'd_reb': 7, 'assist': 2, 'pf': 2, 'stl': 0, 'to': 3, 'blk': 0, 'pts': 11}
# {'box_score_id': 3, 'player_id': '732958', 'minutes_played': 24, 'fg': 5, 'fg_a': 9, 'two_pt': 2, 'two_pt_a': 4, 'three_pt': 3, 'three_pt_a': 5, 'ft': 5, 'ft_a': 7, 'o_reb': 1, 'd_reb': 2, 'assist': 1, 'pf': 3, 'stl': 3, 'to': 3, 'blk': 0, 'pts': 18}
# {'box_score_id': 3, 'player_id': '736429', 'minutes_played': 30, 'fg': 4, 'fg_a': 12, 'two_pt': 3, 'two_pt_a': 9, 'three_pt': 1, 'three_pt_a': 3, 'ft': 3, 'ft_a': 5, 'o_reb': 1, 'd_reb': 5, 'assist': 3, 'pf': 2, 'stl': 1, 'to': 1, 'blk': 0, 'pts': 12}
# {'box_score_id': 3, 'player_id': '741258', 'minutes_played': 19, 'fg': 1, 'fg_a': 5, 'two_pt': 1, 'two_pt_a': 4, 'three_pt': 0, 'three_pt_a': 1, 'ft': 1, 'ft_a': 1, 'o_reb': 1, 'd_reb': 1, 'assist': 1, 'pf': 1, 'stl': 1, 'to': 0, 'blk': 0, 'pts': 3}
# {'box_score_id': 3, 'player_id': '744249', 'minutes_played': 5, 'fg': 1, 'fg_a': 4, 'two_pt': 1, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 2, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 1, 'assist': 1, 'pf': 1, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 2}
# {'box_score_id': 3, 'player_id': '736431', 'minutes_played': 11, 'fg': 0, 'fg_a': 2, 'two_pt': 0, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 1, 'assist': 0, 'pf': 1, 'stl': 0, 'to': 2, 'blk': 0, 'pts': 0}
# {'box_score_id': 3, 'player_id': '747662', 'minutes_played': 21, 'fg': 3, 'fg_a': 5, 'two_pt': 1, 'two_pt_a': 3, 'three_pt': 2, 'three_pt_a': 2, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 3, 'assist': 1, 'pf': 2, 'stl': 0, 'to': 2, 'blk': 1, 'pts': 8}
# {'box_score_id': 3, 'player_id': '744254', 'minutes_played': 10, 'fg': 0, 'fg_a': 1, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 1, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 1, 'assist': 0, 'pf': 1, 'stl': 1, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 3, 'player_id': '744253', 'minutes_played': 10, 'fg': 0, 'fg_a': 3, 'two_pt': 0, 'two_pt_a': 3, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 2, 'assist': 1, 'pf': 1, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 3, 'player_id': '744252', 'minutes_played': 5, 'fg': 0, 'fg_a': 1, 'two_pt': 0, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 1, 'assist': 0, 'pf': 4, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 0}
# {'box_score_id': 4, 'player_id': '736241', 'minutes_played': 25, 'fg': 6, 'fg_a': 10, 'two_pt': 5, 'two_pt_a': 8, 'three_pt': 1, 'three_pt_a': 2, 'ft': 3, 'ft_a': 4, 'o_reb': 2, 'd_reb': 5, 'assist': 2, 'pf': 3, 'stl': 1, 'to': 3, 'blk': 0, 'pts': 16}
# {'box_score_id': 4, 'player_id': '736239', 'minutes_played': 27, 'fg': 4, 'fg_a': 7, 'two_pt': 4, 'two_pt_a': 7, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 2, 'd_reb': 4, 'assist': 0, 'pf': 3, 'stl': 2, 'to': 4, 'blk': 4, 'pts': 8}
# {'box_score_id': 4, 'player_id': '743741', 'minutes_played': 32, 'fg': 6, 'fg_a': 10, 'two_pt': 6, 'two_pt_a': 10, 'three_pt': 0, 'three_pt_a': 0, 'ft': 5, 'ft_a': 6, 'o_reb': 5, 'd_reb': 10, 'assist': 1, 'pf': 2, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 17}
# {'box_score_id': 4, 'player_id': '736237', 'minutes_played': 12, 'fg': 2, 'fg_a': 5, 'two_pt': 2, 'two_pt_a': 4, 'three_pt': 0, 'three_pt_a': 1, 'ft': 5, 'ft_a': 5, 'o_reb': 0, 'd_reb': 2, 'assist': 2, 'pf': 2, 'stl': 1, 'to': 7, 'blk': 0, 'pts': 9}
# {'box_score_id': 4, 'player_id': '740128', 'minutes_played': 29, 'fg': 6, 'fg_a': 8, 'two_pt': 5, 'two_pt_a': 6, 'three_pt': 1, 'three_pt_a': 2, 'ft': 8, 'ft_a': 10, 'o_reb': 0, 'd_reb': 4, 'assist': 4, 'pf': 2, 'stl': 0, 'to': 1, 'blk': 1, 'pts': 21}
# {'box_score_id': 4, 'player_id': '747990', 'minutes_played': 4, 'fg': 2, 'fg_a': 2, 'two_pt': 2, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 3, 'stl': 0, 'to': 2, 'blk': 3, 'pts': 4}
# {'box_score_id': 4, 'player_id': '747993', 'minutes_played': 7, 'fg': 2, 'fg_a': 3, 'two_pt': 2, 'two_pt_a': 3, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 1, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 4}
# {'box_score_id': 4, 'player_id': '747994', 'minutes_played': 18, 'fg': 3, 'fg_a': 7, 'two_pt': 3, 'two_pt_a': 7, 'three_pt': 0, 'three_pt_a': 0, 'ft': 9, 'ft_a': 9, 'o_reb': 0, 'd_reb': 1, 'assist': 5, 'pf': 2, 'stl': 2, 'to': 4, 'blk': 0, 'pts': 15}
# {'box_score_id': 4, 'player_id': '747996', 'minutes_played': 6, 'fg': 0, 'fg_a': 2, 'two_pt': 0, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 1, 'ft': 1, 'ft_a': 2, 'o_reb': 2, 'd_reb': 1, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 1}
# {'box_score_id': 4, 'player_id': '743738', 'minutes_played': 2, 'fg': 0, 'fg_a': 1, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 1, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 0, 'assist': 1, 'pf': 0, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 0}
# {'box_score_id': 4, 'player_id': '747997', 'minutes_played': 24, 'fg': 2, 'fg_a': 4, 'two_pt': 2, 'two_pt_a': 3, 'three_pt': 0, 'three_pt_a': 1, 'ft': 1, 'ft_a': 2, 'o_reb': 0, 'd_reb': 3, 'assist': 8, 'pf': 2, 'stl': 3, 'to': 3, 'blk': 0, 'pts': 5}
# {'box_score_id': 4, 'player_id': '743739', 'minutes_played': 11, 'fg': 2, 'fg_a': 3, 'two_pt': 2, 'two_pt_a': 3, 'three_pt': 0, 'three_pt_a': 0, 'ft': 1, 'ft_a': 2, 'o_reb': 1, 'd_reb': 0, 'assist': 0, 'pf': 1, 'stl': 0, 'to': 2, 'blk': 1, 'pts': 5}
# {'box_score_id': 4, 'player_id': '748000', 'minutes_played': 3, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 5, 'player_id': '744414', 'minutes_played': 28, 'fg': 4, 'fg_a': 11, 'two_pt': 4, 'two_pt_a': 9, 'three_pt': 0, 'three_pt_a': 2, 'ft': 2, 'ft_a': 2, 'o_reb': 3, 'd_reb': 7, 'assist': 4, 'pf': 2, 'stl': 5, 'to': 2, 'blk': 1, 'pts': 10}
# {'box_score_id': 5, 'player_id': '744429', 'minutes_played': 20, 'fg': 1, 'fg_a': 6, 'two_pt': 1, 'two_pt_a': 6, 'three_pt': 0, 'three_pt_a': 0, 'ft': 2, 'ft_a': 4, 'o_reb': 4, 'd_reb': 0, 'assist': 0, 'pf': 4, 'stl': 1, 'to': 4, 'blk': 0, 'pts': 4}
# {'box_score_id': 5, 'player_id': '744413', 'minutes_played': 28, 'fg': 2, 'fg_a': 3, 'two_pt': 2, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 1, 'ft': 2, 'ft_a': 2, 'o_reb': 1, 'd_reb': 3, 'assist': 2, 'pf': 3, 'stl': 7, 'to': 2, 'blk': 0, 'pts': 6}
# {'box_score_id': 5, 'player_id': '747151', 'minutes_played': 29, 'fg': 6, 'fg_a': 17, 'two_pt': 6, 'two_pt_a': 17, 'three_pt': 0, 'three_pt_a': 0, 'ft': 1, 'ft_a': 2, 'o_reb': 0, 'd_reb': 1, 'assist': 2, 'pf': 5, 'stl': 1, 'to': 7, 'blk': 0, 'pts': 13}
# {'box_score_id': 5, 'player_id': '744238', 'minutes_played': 23, 'fg': 5, 'fg_a': 14, 'two_pt': 4, 'two_pt_a': 10, 'three_pt': 1, 'three_pt_a': 4, 'ft': 0, 'ft_a': 1, 'o_reb': 2, 'd_reb': 0, 'assist': 2, 'pf': 4, 'stl': 1, 'to': 5, 'blk': 0, 'pts': 11}
# {'box_score_id': 5, 'player_id': '748314', 'minutes_played': 13, 'fg': 1, 'fg_a': 1, 'two_pt': 1, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 1, 'assist': 0, 'pf': 2, 'stl': 0, 'to': 2, 'blk': 0, 'pts': 2}
# {'box_score_id': 5, 'player_id': '748309', 'minutes_played': 5, 'fg': 0, 'fg_a': 3, 'two_pt': 0, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 2, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 5, 'player_id': '748308', 'minutes_played': 7, 'fg': 0, 'fg_a': 4, 'two_pt': 0, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 3, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 1, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 5, 'player_id': '748304', 'minutes_played': 16, 'fg': 1, 'fg_a': 1, 'two_pt': 1, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 3, 'assist': 0, 'pf': 2, 'stl': 1, 'to': 1, 'blk': 0, 'pts': 2}
# {'box_score_id': 5, 'player_id': '747347', 'minutes_played': 10, 'fg': 2, 'fg_a': 5, 'two_pt': 0, 'two_pt_a': 2, 'three_pt': 2, 'three_pt_a': 3, 'ft': 2, 'ft_a': 2, 'o_reb': 2, 'd_reb': 0, 'assist': 1, 'pf': 5, 'stl': 0, 'to': 4, 'blk': 0, 'pts': 8}
# {'box_score_id': 5, 'player_id': '744436', 'minutes_played': 21, 'fg': 6, 'fg_a': 12, 'two_pt': 6, 'two_pt_a': 11, 'three_pt': 0, 'three_pt_a': 1, 'ft': 8, 'ft_a': 9, 'o_reb': 1, 'd_reb': 0, 'assist': 0, 'pf': 4, 'stl': 2, 'to': 0, 'blk': 0, 'pts': 20}
# {'box_score_id': 6, 'player_id': '737200', 'minutes_played': 28, 'fg': 6, 'fg_a': 8, 'two_pt': 6, 'two_pt_a': 8, 'three_pt': 0, 'three_pt_a': 0, 'ft': 5, 'ft_a': 8, 'o_reb': 2, 'd_reb': 8, 'assist': 2, 'pf': 2, 'stl': 0, 'to': 3, 'blk': 1, 'pts': 17}
# {'box_score_id': 6, 'player_id': '744025', 'minutes_played': 26, 'fg': 10, 'fg_a': 17, 'two_pt': 7, 'two_pt_a': 9, 'three_pt': 3, 'three_pt_a': 8, 'ft': 3, 'ft_a': 3, 'o_reb': 2, 'd_reb': 8, 'assist': 1, 'pf': 2, 'stl': 0, 'to': 1, 'blk': 1, 'pts': 26}
# {'box_score_id': 6, 'player_id': '747534', 'minutes_played': 25, 'fg': 2, 'fg_a': 7, 'two_pt': 2, 'two_pt_a': 4, 'three_pt': 0, 'three_pt_a': 3, 'ft': 1, 'ft_a': 2, 'o_reb': 1, 'd_reb': 3, 'assist': 3, 'pf': 4, 'stl': 0, 'to': 3, 'blk': 0, 'pts': 5}
# {'box_score_id': 6, 'player_id': '732681', 'minutes_played': 14, 'fg': 0, 'fg_a': 1, 'two_pt': 0, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 2, 'assist': 0, 'pf': 1, 'stl': 0, 'to': 0, 'blk': 1, 'pts': 0}
# {'box_score_id': 6, 'player_id': '737198', 'minutes_played': 22, 'fg': 1, 'fg_a': 3, 'two_pt': 1, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 1, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 2, 'assist': 1, 'pf': 3, 'stl': 1, 'to': 1, 'blk': 2, 'pts': 2}
# {'box_score_id': 6, 'player_id': '747536', 'minutes_played': 25, 'fg': 4, 'fg_a': 10, 'two_pt': 4, 'two_pt_a': 10, 'three_pt': 0, 'three_pt_a': 0, 'ft': 4, 'ft_a': 10, 'o_reb': 1, 'd_reb': 6, 'assist': 1, 'pf': 1, 'stl': 1, 'to': 1, 'blk': 0, 'pts': 12}
# {'box_score_id': 6, 'player_id': '744021', 'minutes_played': 23, 'fg': 2, 'fg_a': 4, 'two_pt': 1, 'two_pt_a': 1, 'three_pt': 1, 'three_pt_a': 3, 'ft': 2, 'ft_a': 4, 'o_reb': 0, 'd_reb': 4, 'assist': 6, 'pf': 1, 'stl': 1, 'to': 5, 'blk': 0, 'pts': 7}
# {'box_score_id': 6, 'player_id': '737201', 'minutes_played': 13, 'fg': 3, 'fg_a': 3, 'two_pt': 3, 'two_pt_a': 3, 'three_pt': 0, 'three_pt_a': 0, 'ft': 2, 'ft_a': 4, 'o_reb': 1, 'd_reb': 1, 'assist': 0, 'pf': 0, 'stl': 2, 'to': 0, 'blk': 0, 'pts': 8}
# {'box_score_id': 6, 'player_id': '736734', 'minutes_played': 24, 'fg': 2, 'fg_a': 6, 'two_pt': 2, 'two_pt_a': 4, 'three_pt': 0, 'three_pt_a': 2, 'ft': 2, 'ft_a': 3, 'o_reb': 1, 'd_reb': 1, 'assist': 2, 'pf': 3, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 6}
# {'box_score_id': 7, 'player_id': '733899', 'minutes_played': 30, 'fg': 1, 'fg_a': 3, 'two_pt': 1, 'two_pt_a': 3, 'three_pt': 0, 'three_pt_a': 0, 'ft': 4, 'ft_a': 6, 'o_reb': 0, 'd_reb': 1, 'assist': 3, 'pf': 4, 'stl': 1, 'to': 3, 'blk': 0, 'pts': 6}
# {'box_score_id': 7, 'player_id': '740398', 'minutes_played': 32, 'fg': 3, 'fg_a': 14, 'two_pt': 2, 'two_pt_a': 6, 'three_pt': 1, 'three_pt_a': 8, 'ft': 1, 'ft_a': 2, 'o_reb': 0, 'd_reb': 4, 'assist': 2, 'pf': 2, 'stl': 1, 'to': 4, 'blk': 0, 'pts': 8}
# {'box_score_id': 7, 'player_id': '736729', 'minutes_played': 29, 'fg': 6, 'fg_a': 16, 'two_pt': 6, 'two_pt_a': 16, 'three_pt': 0, 'three_pt_a': 0, 'ft': 2, 'ft_a': 2, 'o_reb': 2, 'd_reb': 6, 'assist': 0, 'pf': 5, 'stl': 0, 'to': 2, 'blk': 5, 'pts': 14}
# {'box_score_id': 7, 'player_id': '736728', 'minutes_played': 29, 'fg': 2, 'fg_a': 6, 'two_pt': 2, 'two_pt_a': 4, 'three_pt': 0, 'three_pt_a': 2, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 1, 'assist': 1, 'pf': 1, 'stl': 1, 'to': 2, 'blk': 0, 'pts': 4}
# {'box_score_id': 7, 'player_id': '749063', 'minutes_played': 14, 'fg': 1, 'fg_a': 5, 'two_pt': 0, 'two_pt_a': 2, 'three_pt': 1, 'three_pt_a': 3, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 2, 'assist': 0, 'pf': 5, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 3}
# {'box_score_id': 7, 'player_id': '749070', 'minutes_played': 16, 'fg': 2, 'fg_a': 6, 'two_pt': 2, 'two_pt_a': 4, 'three_pt': 0, 'three_pt_a': 2, 'ft': 0, 'ft_a': 2, 'o_reb': 1, 'd_reb': 1, 'assist': 0, 'pf': 3, 'stl': 1, 'to': 0, 'blk': 0, 'pts': 4}
# {'box_score_id': 7, 'player_id': '736727', 'minutes_played': 14, 'fg': 2, 'fg_a': 6, 'two_pt': 0, 'two_pt_a': 3, 'three_pt': 2, 'three_pt_a': 3, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 2, 'assist': 1, 'pf': 1, 'stl': 1, 'to': 0, 'blk': 0, 'pts': 6}
# {'box_score_id': 7, 'player_id': '749072', 'minutes_played': 8, 'fg': 1, 'fg_a': 2, 'two_pt': 1, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 1, 'ft': 1, 'ft_a': 3, 'o_reb': 0, 'd_reb': 1, 'assist': 1, 'pf': 1, 'stl': 0, 'to': 3, 'blk': 0, 'pts': 3}
# {'box_score_id': 7, 'player_id': '740396', 'minutes_played': 2, 'fg': 1, 'fg_a': 1, 'two_pt': 1, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 2}
# {'box_score_id': 7, 'player_id': '747279', 'minutes_played': 4, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 0}
# {'box_score_id': 7, 'player_id': '749068', 'minutes_played': 15, 'fg': 0, 'fg_a': 3, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 3, 'ft': 2, 'ft_a': 2, 'o_reb': 0, 'd_reb': 2, 'assist': 0, 'pf': 2, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 2}
# {'box_score_id': 7, 'player_id': '749074', 'minutes_played': 4, 'fg': 0, 'fg_a': 1, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 1, 'ft': 0, 'ft_a': 1, 'o_reb': 0, 'd_reb': 1, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 0}
# {'box_score_id': 7, 'player_id': '749065', 'minutes_played': 3, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 8, 'player_id': '732784', 'minutes_played': 21, 'fg': 4, 'fg_a': 8, 'two_pt': 3, 'two_pt_a': 6, 'three_pt': 1, 'three_pt_a': 2, 'ft': 3, 'ft_a': 4, 'o_reb': 2, 'd_reb': 4, 'assist': 3, 'pf': 2, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 12}
# {'box_score_id': 8, 'player_id': '737212', 'minutes_played': 20, 'fg': 4, 'fg_a': 6, 'two_pt': 4, 'two_pt_a': 6, 'three_pt': 0, 'three_pt_a': 0, 'ft': 1, 'ft_a': 3, 'o_reb': 1, 'd_reb': 7, 'assist': 0, 'pf': 2, 'stl': 1, 'to': 2, 'blk': 1, 'pts': 9}
# {'box_score_id': 8, 'player_id': '737213', 'minutes_played': 25, 'fg': 7, 'fg_a': 8, 'two_pt': 6, 'two_pt_a': 7, 'three_pt': 1, 'three_pt_a': 1, 'ft': 2, 'ft_a': 3, 'o_reb': 3, 'd_reb': 3, 'assist': 9, 'pf': 1, 'stl': 1, 'to': 2, 'blk': 0, 'pts': 17}
# {'box_score_id': 8, 'player_id': '744163', 'minutes_played': 18, 'fg': 4, 'fg_a': 6, 'two_pt': 4, 'two_pt_a': 6, 'three_pt': 0, 'three_pt_a': 0, 'ft': 1, 'ft_a': 2, 'o_reb': 7, 'd_reb': 1, 'assist': 0, 'pf': 1, 'stl': 0, 'to': 2, 'blk': 2, 'pts': 9}
# {'box_score_id': 8, 'player_id': '740474', 'minutes_played': 30, 'fg': 8, 'fg_a': 14, 'two_pt': 3, 'two_pt_a': 4, 'three_pt': 5, 'three_pt_a': 10, 'ft': 3, 'ft_a': 4, 'o_reb': 0, 'd_reb': 0, 'assist': 7, 'pf': 1, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 24}
# {'box_score_id': 8, 'player_id': '744165', 'minutes_played': 17, 'fg': 1, 'fg_a': 2, 'two_pt': 1, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 2, 'd_reb': 3, 'assist': 0, 'pf': 0, 'stl': 1, 'to': 0, 'blk': 1, 'pts': 2}
# {'box_score_id': 8, 'player_id': '744164', 'minutes_played': 20, 'fg': 3, 'fg_a': 6, 'two_pt': 1, 'two_pt_a': 2, 'three_pt': 2, 'three_pt_a': 4, 'ft': 2, 'ft_a': 2, 'o_reb': 0, 'd_reb': 3, 'assist': 2, 'pf': 2, 'stl': 1, 'to': 1, 'blk': 0, 'pts': 10}
# {'box_score_id': 8, 'player_id': '747643', 'minutes_played': 17, 'fg': 4, 'fg_a': 7, 'two_pt': 3, 'two_pt_a': 5, 'three_pt': 1, 'three_pt_a': 2, 'ft': 0, 'ft_a': 1, 'o_reb': 1, 'd_reb': 2, 'assist': 2, 'pf': 2, 'stl': 1, 'to': 4, 'blk': 0, 'pts': 9}
# {'box_score_id': 8, 'player_id': '744156', 'minutes_played': 21, 'fg': 1, 'fg_a': 4, 'two_pt': 0, 'two_pt_a': 2, 'three_pt': 1, 'three_pt_a': 2, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 2, 'assist': 2, 'pf': 1, 'stl': 0, 'to': 0, 'blk': 1, 'pts': 3}
# {'box_score_id': 8, 'player_id': '744158', 'minutes_played': 7, 'fg': 1, 'fg_a': 2, 'two_pt': 1, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 1, 'o_reb': 0, 'd_reb': 1, 'assist': 1, 'pf': 1, 'stl': 0, 'to': 0, 'blk': 2, 'pts': 2}
# {'box_score_id': 8, 'player_id': '747645', 'minutes_played': 2, 'fg': 0, 'fg_a': 1, 'two_pt': 0, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 8, 'player_id': '744160', 'minutes_played': 2, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 1, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 9, 'player_id': '744717', 'minutes_played': 22, 'fg': 2, 'fg_a': 4, 'two_pt': 2, 'two_pt_a': 4, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 2, 'd_reb': 1, 'assist': 1, 'pf': 4, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 4}
# {'box_score_id': 9, 'player_id': '740636', 'minutes_played': 24, 'fg': 1, 'fg_a': 10, 'two_pt': 1, 'two_pt_a': 7, 'three_pt': 0, 'three_pt_a': 3, 'ft': 4, 'ft_a': 5, 'o_reb': 0, 'd_reb': 4, 'assist': 2, 'pf': 3, 'stl': 0, 'to': 4, 'blk': 1, 'pts': 6}
# {'box_score_id': 9, 'player_id': '744726', 'minutes_played': 31, 'fg': 2, 'fg_a': 8, 'two_pt': 2, 'two_pt_a': 5, 'three_pt': 0, 'three_pt_a': 3, 'ft': 3, 'ft_a': 4, 'o_reb': 0, 'd_reb': 3, 'assist': 1, 'pf': 0, 'stl': 0, 'to': 2, 'blk': 0, 'pts': 7}
# {'box_score_id': 9, 'player_id': '748188', 'minutes_played': 13, 'fg': 1, 'fg_a': 5, 'two_pt': 1, 'two_pt_a': 5, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 1, 'assist': 0, 'pf': 4, 'stl': 0, 'to': 0, 'blk': 1, 'pts': 2}
# {'box_score_id': 9, 'player_id': '744729', 'minutes_played': 21, 'fg': 6, 'fg_a': 10, 'two_pt': 6, 'two_pt_a': 10, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 2, 'd_reb': 3, 'assist': 2, 'pf': 1, 'stl': 0, 'to': 2, 'blk': 1, 'pts': 12}
# {'box_score_id': 9, 'player_id': '740898', 'minutes_played': 29, 'fg': 3, 'fg_a': 9, 'two_pt': 3, 'two_pt_a': 9, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 0, 'assist': 0, 'pf': 3, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 6}
# {'box_score_id': 9, 'player_id': '739869', 'minutes_played': 19, 'fg': 2, 'fg_a': 3, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 2, 'three_pt_a': 3, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 1, 'assist': 0, 'pf': 1, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 6}
# {'box_score_id': 9, 'player_id': '744719', 'minutes_played': 14, 'fg': 2, 'fg_a': 2, 'two_pt': 1, 'two_pt_a': 1, 'three_pt': 1, 'three_pt_a': 1, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 1, 'assist': 1, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 5}
# {'box_score_id': 9, 'player_id': '748186', 'minutes_played': 6, 'fg': 2, 'fg_a': 2, 'two_pt': 2, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 1, 'assist': 1, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 4}
# {'box_score_id': 9, 'player_id': '739555', 'minutes_played': 3, 'fg': 0, 'fg_a': 1, 'two_pt': 0, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 1, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 9, 'player_id': '744731', 'minutes_played': 2, 'fg': 1, 'fg_a': 1, 'two_pt': 1, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 1, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 2}
# {'box_score_id': 9, 'player_id': '744725', 'minutes_played': 6, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 9, 'player_id': '744722', 'minutes_played': 4, 'fg': 0, 'fg_a': 1, 'two_pt': 0, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 1, 'pf': 0, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 0}
# {'box_score_id': 9, 'player_id': '747233', 'minutes_played': 2, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 9, 'player_id': '748174', 'minutes_played': 4, 'fg': 0, 'fg_a': 2, 'two_pt': 0, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 10, 'player_id': '737163', 'minutes_played': 18, 'fg': 5, 'fg_a': 7, 'two_pt': 2, 'two_pt_a': 3, 'three_pt': 3, 'three_pt_a': 4, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 2, 'assist': 7, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 13}
# {'box_score_id': 10, 'player_id': '744038', 'minutes_played': 17, 'fg': 1, 'fg_a': 2, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 1, 'three_pt_a': 2, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 2, 'pf': 2, 'stl': 0, 'to': 1, 'blk': 1, 'pts': 3}
# {'box_score_id': 10, 'player_id': '737167', 'minutes_played': 15, 'fg': 5, 'fg_a': 8, 'two_pt': 5, 'two_pt_a': 7, 'three_pt': 0, 'three_pt_a': 1, 'ft': 0, 'ft_a': 1, 'o_reb': 4, 'd_reb': 4, 'assist': 1, 'pf': 3, 'stl': 1, 'to': 2, 'blk': 1, 'pts': 10}
# {'box_score_id': 10, 'player_id': '737160', 'minutes_played': 18, 'fg': 2, 'fg_a': 5, 'two_pt': 1, 'two_pt_a': 1, 'three_pt': 1, 'three_pt_a': 4, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 1, 'assist': 1, 'pf': 2, 'stl': 2, 'to': 0, 'blk': 2, 'pts': 5}
# {'box_score_id': 10, 'player_id': '737161', 'minutes_played': 18, 'fg': 5, 'fg_a': 7, 'two_pt': 5, 'two_pt_a': 7, 'three_pt': 0, 'three_pt_a': 0, 'ft': 2, 'ft_a': 2, 'o_reb': 1, 'd_reb': 5, 'assist': 2, 'pf': 1, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 12}
# {'box_score_id': 10, 'player_id': '747422', 'minutes_played': 22, 'fg': 5, 'fg_a': 7, 'two_pt': 5, 'two_pt_a': 7, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 5, 'assist': 0, 'pf': 3, 'stl': 1, 'to': 2, 'blk': 2, 'pts': 10}
# {'box_score_id': 10, 'player_id': '744037', 'minutes_played': 20, 'fg': 4, 'fg_a': 8, 'two_pt': 4, 'two_pt_a': 5, 'three_pt': 0, 'three_pt_a': 3, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 6, 'assist': 3, 'pf': 0, 'stl': 5, 'to': 2, 'blk': 0, 'pts': 8}
# {'box_score_id': 10, 'player_id': '747423', 'minutes_played': 27, 'fg': 4, 'fg_a': 9, 'two_pt': 4, 'two_pt_a': 8, 'three_pt': 0, 'three_pt_a': 1, 'ft': 0, 'ft_a': 0, 'o_reb': 3, 'd_reb': 1, 'assist': 3, 'pf': 0, 'stl': 0, 'to': 2, 'blk': 0, 'pts': 8}
# {'box_score_id': 10, 'player_id': '744033', 'minutes_played': 22, 'fg': 3, 'fg_a': 7, 'two_pt': 3, 'two_pt_a': 4, 'three_pt': 0, 'three_pt_a': 3, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 3, 'assist': 1, 'pf': 3, 'stl': 0, 'to': 2, 'blk': 0, 'pts': 6}
# {'box_score_id': 10, 'player_id': '744029', 'minutes_played': 17, 'fg': 2, 'fg_a': 3, 'two_pt': 2, 'two_pt_a': 3, 'three_pt': 0, 'three_pt_a': 0, 'ft': 1, 'ft_a': 1, 'o_reb': 0, 'd_reb': 1, 'assist': 1, 'pf': 2, 'stl': 0, 'to': 0, 'blk': 1, 'pts': 5}
# {'box_score_id': 10, 'player_id': '745289', 'minutes_played': 6, 'fg': 1, 'fg_a': 1, 'two_pt': 1, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 0, 'ft': 2, 'ft_a': 2, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 2, 'stl': 1, 'to': 2, 'blk': 0, 'pts': 4}
# {'box_score_id': 11, 'player_id': '737466', 'minutes_played': 17, 'fg': 2, 'fg_a': 5, 'two_pt': 1, 'two_pt_a': 2, 'three_pt': 1, 'three_pt_a': 3, 'ft': 0, 'ft_a': 0, 'o_reb': 2, 'd_reb': 2, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 2, 'blk': 0, 'pts': 5}
# {'box_score_id': 11, 'player_id': '748029', 'minutes_played': 27, 'fg': 5, 'fg_a': 10, 'two_pt': 5, 'two_pt_a': 10, 'three_pt': 0, 'three_pt_a': 0, 'ft': 1, 'ft_a': 3, 'o_reb': 0, 'd_reb': 1, 'assist': 0, 'pf': 2, 'stl': 2, 'to': 2, 'blk': 0, 'pts': 11}
# {'box_score_id': 11, 'player_id': '745096', 'minutes_played': 30, 'fg': 4, 'fg_a': 11, 'two_pt': 4, 'two_pt_a': 9, 'three_pt': 0, 'three_pt_a': 2, 'ft': 2, 'ft_a': 2, 'o_reb': 0, 'd_reb': 2, 'assist': 4, 'pf': 3, 'stl': 3, 'to': 5, 'blk': 0, 'pts': 10}
# {'box_score_id': 11, 'player_id': '748035', 'minutes_played': 32, 'fg': 2, 'fg_a': 6, 'two_pt': 1, 'two_pt_a': 3, 'three_pt': 1, 'three_pt_a': 3, 'ft': 3, 'ft_a': 4, 'o_reb': 0, 'd_reb': 1, 'assist': 1, 'pf': 2, 'stl': 0, 'to': 5, 'blk': 0, 'pts': 8}
# {'box_score_id': 11, 'player_id': '745052', 'minutes_played': 22, 'fg': 2, 'fg_a': 5, 'two_pt': 2, 'two_pt_a': 4, 'three_pt': 0, 'three_pt_a': 1, 'ft': 4, 'ft_a': 6, 'o_reb': 0, 'd_reb': 3, 'assist': 1, 'pf': 2, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 8}
# {'box_score_id': 11, 'player_id': '748032', 'minutes_played': 30, 'fg': 0, 'fg_a': 2, 'two_pt': 0, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 2, 'o_reb': 0, 'd_reb': 1, 'assist': 2, 'pf': 2, 'stl': 0, 'to': 4, 'blk': 0, 'pts': 0}
# {'box_score_id': 11, 'player_id': '748058', 'minutes_played': 14, 'fg': 0, 'fg_a': 2, 'two_pt': 0, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 2, 'o_reb': 1, 'd_reb': 4, 'assist': 0, 'pf': 1, 'stl': 1, 'to': 1, 'blk': 0, 'pts': 0}
# {'box_score_id': 11, 'player_id': '743562', 'minutes_played': 18, 'fg': 1, 'fg_a': 4, 'two_pt': 0, 'two_pt_a': 1, 'three_pt': 1, 'three_pt_a': 3, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 2, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 3}
# {'box_score_id': 11, 'player_id': '748025', 'minutes_played': 10, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 1, 'pf': 2, 'stl': 0, 'to': 3, 'blk': 0, 'pts': 0}
# {'box_score_id': 12, 'player_id': '740128', 'minutes_played': 29, 'fg': 1, 'fg_a': 5, 'two_pt': 1, 'two_pt_a': 5, 'three_pt': 0, 'three_pt_a': 0, 'ft': 1, 'ft_a': 2, 'o_reb': 0, 'd_reb': 2, 'assist': 4, 'pf': 2, 'stl': 1, 'to': 3, 'blk': 1, 'pts': 3}
# {'box_score_id': 12, 'player_id': '736241', 'minutes_played': 31, 'fg': 7, 'fg_a': 15, 'two_pt': 7, 'two_pt_a': 12, 'three_pt': 0, 'three_pt_a': 3, 'ft': 1, 'ft_a': 2, 'o_reb': 2, 'd_reb': 0, 'assist': 2, 'pf': 1, 'stl': 1, 'to': 1, 'blk': 0, 'pts': 15}
# {'box_score_id': 12, 'player_id': '736239', 'minutes_played': 26, 'fg': 0, 'fg_a': 4, 'two_pt': 0, 'two_pt_a': 4, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 2, 'd_reb': 2, 'assist': 0, 'pf': 4, 'stl': 1, 'to': 2, 'blk': 1, 'pts': 0}
# {'box_score_id': 12, 'player_id': '743741', 'minutes_played': 37, 'fg': 12, 'fg_a': 21, 'two_pt': 12, 'two_pt_a': 21, 'three_pt': 0, 'three_pt_a': 0, 'ft': 2, 'ft_a': 8, 'o_reb': 7, 'd_reb': 8, 'assist': 0, 'pf': 3, 'stl': 2, 'to': 2, 'blk': 1, 'pts': 26}
# {'box_score_id': 12, 'player_id': '736237', 'minutes_played': 28, 'fg': 4, 'fg_a': 7, 'two_pt': 3, 'two_pt_a': 5, 'three_pt': 1, 'three_pt_a': 2, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 3, 'assist': 3, 'pf': 2, 'stl': 1, 'to': 2, 'blk': 0, 'pts': 9}
# {'box_score_id': 12, 'player_id': '747994', 'minutes_played': 8, 'fg': 1, 'fg_a': 2, 'two_pt': 1, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 1, 'o_reb': 0, 'd_reb': 1, 'assist': 2, 'pf': 1, 'stl': 3, 'to': 3, 'blk': 0, 'pts': 2}
# {'box_score_id': 12, 'player_id': '743739', 'minutes_played': 4, 'fg': 2, 'fg_a': 3, 'two_pt': 2, 'two_pt_a': 3, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 0, 'assist': 0, 'pf': 1, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 4}
# {'box_score_id': 12, 'player_id': '747997', 'minutes_played': 24, 'fg': 6, 'fg_a': 7, 'two_pt': 5, 'two_pt_a': 6, 'three_pt': 1, 'three_pt_a': 1, 'ft': 1, 'ft_a': 5, 'o_reb': 0, 'd_reb': 1, 'assist': 4, 'pf': 1, 'stl': 2, 'to': 3, 'blk': 0, 'pts': 14}
# {'box_score_id': 12, 'player_id': '747996', 'minutes_played': 10, 'fg': 0, 'fg_a': 1, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 1, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 1, 'assist': 2, 'pf': 1, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 0}
# {'box_score_id': 12, 'player_id': '747990', 'minutes_played': 3, 'fg': 1, 'fg_a': 1, 'two_pt': 1, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 2, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 2}
# {'box_score_id': 13, 'player_id': '739452', 'minutes_played': 39, 'fg': 10, 'fg_a': 18, 'two_pt': 5, 'two_pt_a': 9, 'three_pt': 5, 'three_pt_a': 9, 'ft': 2, 'ft_a': 2, 'o_reb': 2, 'd_reb': 8, 'assist': 3, 'pf': 1, 'stl': 1, 'to': 8, 'blk': 0, 'pts': 27}
# {'box_score_id': 13, 'player_id': '739451', 'minutes_played': 28, 'fg': 3, 'fg_a': 8, 'two_pt': 2, 'two_pt_a': 4, 'three_pt': 1, 'three_pt_a': 4, 'ft': 8, 'ft_a': 8, 'o_reb': 1, 'd_reb': 1, 'assist': 3, 'pf': 4, 'stl': 1, 'to': 4, 'blk': 0, 'pts': 15}
# {'box_score_id': 13, 'player_id': '739453', 'minutes_played': 30, 'fg': 3, 'fg_a': 7, 'two_pt': 3, 'two_pt_a': 6, 'three_pt': 0, 'three_pt_a': 1, 'ft': 4, 'ft_a': 6, 'o_reb': 1, 'd_reb': 0, 'assist': 0, 'pf': 4, 'stl': 0, 'to': 2, 'blk': 1, 'pts': 10}
# {'box_score_id': 13, 'player_id': '739456', 'minutes_played': 36, 'fg': 2, 'fg_a': 5, 'two_pt': 1, 'two_pt_a': 4, 'three_pt': 1, 'three_pt_a': 1, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 7, 'assist': 5, 'pf': 3, 'stl': 2, 'to': 4, 'blk': 5, 'pts': 5}
# {'box_score_id': 13, 'player_id': '745081', 'minutes_played': 26, 'fg': 1, 'fg_a': 6, 'two_pt': 1, 'two_pt_a': 5, 'three_pt': 0, 'three_pt_a': 1, 'ft': 0, 'ft_a': 0, 'o_reb': 2, 'd_reb': 4, 'assist': 0, 'pf': 3, 'stl': 0, 'to': 1, 'blk': 1, 'pts': 2}
# {'box_score_id': 13, 'player_id': '745078', 'minutes_played': 16, 'fg': 3, 'fg_a': 8, 'two_pt': 2, 'two_pt_a': 4, 'three_pt': 1, 'three_pt_a': 4, 'ft': 2, 'ft_a': 3, 'o_reb': 1, 'd_reb': 1, 'assist': 0, 'pf': 2, 'stl': 3, 'to': 2, 'blk': 0, 'pts': 9}
# {'box_score_id': 13, 'player_id': '748767', 'minutes_played': 23, 'fg': 3, 'fg_a': 3, 'two_pt': 3, 'two_pt_a': 3, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 2, 'd_reb': 4, 'assist': 1, 'pf': 2, 'stl': 1, 'to': 1, 'blk': 1, 'pts': 6}
# {'box_score_id': 13, 'player_id': '748761', 'minutes_played': 2, 'fg': 0, 'fg_a': 1, 'two_pt': 0, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 14, 'player_id': '737198', 'minutes_played': 12, 'fg': 4, 'fg_a': 6, 'two_pt': 4, 'two_pt_a': 6, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 2, 'd_reb': 5, 'assist': 3, 'pf': 2, 'stl': 1, 'to': 0, 'blk': 1, 'pts': 8}
# {'box_score_id': 14, 'player_id': '744025', 'minutes_played': 30, 'fg': 6, 'fg_a': 16, 'two_pt': 5, 'two_pt_a': 10, 'three_pt': 1, 'three_pt_a': 6, 'ft': 6, 'ft_a': 7, 'o_reb': 1, 'd_reb': 3, 'assist': 2, 'pf': 0, 'stl': 2, 'to': 1, 'blk': 0, 'pts': 19}
# {'box_score_id': 14, 'player_id': '732681', 'minutes_played': 19, 'fg': 1, 'fg_a': 2, 'two_pt': 1, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 2, 'd_reb': 1, 'assist': 1, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 3, 'pts': 2}
# {'box_score_id': 14, 'player_id': '737200', 'minutes_played': 28, 'fg': 6, 'fg_a': 10, 'two_pt': 6, 'two_pt_a': 10, 'three_pt': 0, 'three_pt_a': 0, 'ft': 3, 'ft_a': 5, 'o_reb': 2, 'd_reb': 4, 'assist': 1, 'pf': 4, 'stl': 1, 'to': 0, 'blk': 0, 'pts': 15}
# {'box_score_id': 14, 'player_id': '747534', 'minutes_played': 37, 'fg': 3, 'fg_a': 9, 'two_pt': 1, 'two_pt_a': 5, 'three_pt': 2, 'three_pt_a': 4, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 7, 'assist': 4, 'pf': 1, 'stl': 4, 'to': 2, 'blk': 0, 'pts': 8}
# {'box_score_id': 14, 'player_id': '747536', 'minutes_played': 25, 'fg': 6, 'fg_a': 11, 'two_pt': 6, 'two_pt_a': 11, 'three_pt': 0, 'three_pt_a': 0, 'ft': 5, 'ft_a': 7, 'o_reb': 4, 'd_reb': 3, 'assist': 2, 'pf': 4, 'stl': 3, 'to': 3, 'blk': 3, 'pts': 17}
# {'box_score_id': 14, 'player_id': '744021', 'minutes_played': 17, 'fg': 2, 'fg_a': 8, 'two_pt': 2, 'two_pt_a': 5, 'three_pt': 0, 'three_pt_a': 3, 'ft': 1, 'ft_a': 1, 'o_reb': 1, 'd_reb': 0, 'assist': 2, 'pf': 4, 'stl': 0, 'to': 3, 'blk': 0, 'pts': 5}
# {'box_score_id': 14, 'player_id': '736734', 'minutes_played': 14, 'fg': 3, 'fg_a': 6, 'two_pt': 3, 'two_pt_a': 5, 'three_pt': 0, 'three_pt_a': 1, 'ft': 2, 'ft_a': 2, 'o_reb': 0, 'd_reb': 0, 'assist': 3, 'pf': 3, 'stl': 1, 'to': 3, 'blk': 0, 'pts': 8}
# {'box_score_id': 14, 'player_id': '737201', 'minutes_played': 15, 'fg': 2, 'fg_a': 4, 'two_pt': 2, 'two_pt_a': 4, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 4, 'assist': 0, 'pf': 3, 'stl': 0, 'to': 2, 'blk': 0, 'pts': 4}
# {'box_score_id': 14, 'player_id': '749140', 'minutes_played': 1, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 14, 'player_id': '744030', 'minutes_played': 1, 'fg': 1, 'fg_a': 2, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 1, 'three_pt_a': 2, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 3}
# {'box_score_id': 14, 'player_id': '744024', 'minutes_played': 1, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 1, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 15, 'player_id': '737602', 'minutes_played': 26, 'fg': 4, 'fg_a': 7, 'two_pt': 4, 'two_pt_a': 6, 'three_pt': 0, 'three_pt_a': 1, 'ft': 5, 'ft_a': 9, 'o_reb': 0, 'd_reb': 11, 'assist': 1, 'pf': 5, 'stl': 2, 'to': 6, 'blk': 0, 'pts': 13}
# {'box_score_id': 15, 'player_id': '745482', 'minutes_played': 20, 'fg': 3, 'fg_a': 10, 'two_pt': 3, 'two_pt_a': 10, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 0, 'assist': 1, 'pf': 3, 'stl': 1, 'to': 6, 'blk': 0, 'pts': 6}
# {'box_score_id': 15, 'player_id': '743263', 'minutes_played': 30, 'fg': 5, 'fg_a': 14, 'two_pt': 4, 'two_pt_a': 10, 'three_pt': 1, 'three_pt_a': 4, 'ft': 5, 'ft_a': 7, 'o_reb': 2, 'd_reb': 1, 'assist': 0, 'pf': 1, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 16}
# {'box_score_id': 15, 'player_id': '745485', 'minutes_played': 25, 'fg': 2, 'fg_a': 7, 'two_pt': 1, 'two_pt_a': 4, 'three_pt': 1, 'three_pt_a': 3, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 2, 'assist': 0, 'pf': 1, 'stl': 1, 'to': 1, 'blk': 0, 'pts': 5}
# {'box_score_id': 15, 'player_id': '749080', 'minutes_played': 14, 'fg': 0, 'fg_a': 2, 'two_pt': 0, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 2, 'd_reb': 0, 'assist': 0, 'pf': 2, 'stl': 0, 'to': 2, 'blk': 1, 'pts': 0}
# {'box_score_id': 15, 'player_id': '745438', 'minutes_played': 15, 'fg': 0, 'fg_a': 2, 'two_pt': 0, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 2, 'd_reb': 2, 'assist': 0, 'pf': 3, 'stl': 1, 'to': 2, 'blk': 2, 'pts': 0}
# {'box_score_id': 15, 'player_id': '747245', 'minutes_played': 16, 'fg': 0, 'fg_a': 2, 'two_pt': 0, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 2, 'assist': 0, 'pf': 2, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 15, 'player_id': '749076', 'minutes_played': 12, 'fg': 3, 'fg_a': 5, 'two_pt': 2, 'two_pt_a': 3, 'three_pt': 1, 'three_pt_a': 2, 'ft': 2, 'ft_a': 2, 'o_reb': 0, 'd_reb': 1, 'assist': 0, 'pf': 0, 'stl': 1, 'to': 1, 'blk': 0, 'pts': 9}
# {'box_score_id': 15, 'player_id': '749075', 'minutes_played': 16, 'fg': 3, 'fg_a': 5, 'two_pt': 3, 'two_pt_a': 5, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 4, 'd_reb': 2, 'assist': 1, 'pf': 1, 'stl': 0, 'to': 1, 'blk': 2, 'pts': 6}
# {'box_score_id': 15, 'player_id': '749083', 'minutes_played': 14, 'fg': 1, 'fg_a': 5, 'two_pt': 1, 'two_pt_a': 3, 'three_pt': 0, 'three_pt_a': 2, 'ft': 1, 'ft_a': 2, 'o_reb': 1, 'd_reb': 2, 'assist': 1, 'pf': 1, 'stl': 0, 'to': 2, 'blk': 0, 'pts': 3}
# {'box_score_id': 15, 'player_id': '749071', 'minutes_played': 8, 'fg': 0, 'fg_a': 3, 'two_pt': 0, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 1, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 1, 'assist': 0, 'pf': 2, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 15, 'player_id': '745487', 'minutes_played': 4, 'fg': 0, 'fg_a': 2, 'two_pt': 0, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 1, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 1, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 0}
# {'box_score_id': 16, 'player_id': '733268', 'minutes_played': 30, 'fg': 3, 'fg_a': 6, 'two_pt': 3, 'two_pt_a': 6, 'three_pt': 0, 'three_pt_a': 0, 'ft': 1, 'ft_a': 3, 'o_reb': 3, 'd_reb': 8, 'assist': 2, 'pf': 2, 'stl': 1, 'to': 2, 'blk': 0, 'pts': 7}
# {'box_score_id': 16, 'player_id': '736937', 'minutes_played': 23, 'fg': 4, 'fg_a': 6, 'two_pt': 4, 'two_pt_a': 6, 'three_pt': 0, 'three_pt_a': 0, 'ft': 3, 'ft_a': 3, 'o_reb': 2, 'd_reb': 0, 'assist': 2, 'pf': 2, 'stl': 0, 'to': 1, 'blk': 3, 'pts': 11}
# {'box_score_id': 16, 'player_id': '736939', 'minutes_played': 30, 'fg': 1, 'fg_a': 7, 'two_pt': 0, 'two_pt_a': 3, 'three_pt': 1, 'three_pt_a': 4, 'ft': 6, 'ft_a': 8, 'o_reb': 1, 'd_reb': 3, 'assist': 4, 'pf': 1, 'stl': 1, 'to': 1, 'blk': 0, 'pts': 9}
# {'box_score_id': 16, 'player_id': '736938', 'minutes_played': 26, 'fg': 5, 'fg_a': 12, 'two_pt': 3, 'two_pt_a': 5, 'three_pt': 2, 'three_pt_a': 7, 'ft': 13, 'ft_a': 16, 'o_reb': 1, 'd_reb': 1, 'assist': 2, 'pf': 2, 'stl': 3, 'to': 2, 'blk': 0, 'pts': 25}
# {'box_score_id': 16, 'player_id': '736878', 'minutes_played': 13, 'fg': 0, 'fg_a': 2, 'two_pt': 0, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 1, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 2, 'assist': 1, 'pf': 1, 'stl': 0, 'to': 2, 'blk': 1, 'pts': 0}
# {'box_score_id': 16, 'player_id': '733616', 'minutes_played': 30, 'fg': 6, 'fg_a': 7, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 6, 'three_pt_a': 7, 'ft': 3, 'ft_a': 5, 'o_reb': 0, 'd_reb': 0, 'assist': 3, 'pf': 1, 'stl': 0, 'to': 3, 'blk': 0, 'pts': 21}
# {'box_score_id': 16, 'player_id': '748601', 'minutes_played': 4, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 2, 'ft_a': 2, 'o_reb': 0, 'd_reb': 1, 'assist': 0, 'pf': 0, 'stl': 1, 'to': 0, 'blk': 0, 'pts': 2}
# {'box_score_id': 16, 'player_id': '741321', 'minutes_played': 10, 'fg': 0, 'fg_a': 1, 'two_pt': 0, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 2, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 0}
# {'box_score_id': 16, 'player_id': '745447', 'minutes_played': 13, 'fg': 1, 'fg_a': 6, 'two_pt': 1, 'two_pt_a': 5, 'three_pt': 0, 'three_pt_a': 1, 'ft': 5, 'ft_a': 6, 'o_reb': 4, 'd_reb': 4, 'assist': 1, 'pf': 4, 'stl': 0, 'to': 0, 'blk': 2, 'pts': 7}
# {'box_score_id': 16, 'player_id': '747138', 'minutes_played': 10, 'fg': 2, 'fg_a': 6, 'two_pt': 1, 'two_pt_a': 2, 'three_pt': 1, 'three_pt_a': 4, 'ft': 1, 'ft_a': 2, 'o_reb': 0, 'd_reb': 2, 'assist': 2, 'pf': 1, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 6}
# {'box_score_id': 16, 'player_id': '737189', 'minutes_played': 11, 'fg': 1, 'fg_a': 3, 'two_pt': 1, 'two_pt_a': 3, 'three_pt': 0, 'three_pt_a': 0, 'ft': 2, 'ft_a': 2, 'o_reb': 3, 'd_reb': 1, 'assist': 0, 'pf': 3, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 4}
# {'box_score_id': 18, 'player_id': '740199', 'minutes_played': 17, 'fg': 3, 'fg_a': 7, 'two_pt': 0, 'two_pt_a': 3, 'three_pt': 3, 'three_pt_a': 4, 'ft': 2, 'ft_a': 2, 'o_reb': 1, 'd_reb': 4, 'assist': 1, 'pf': 4, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 11}
# {'box_score_id': 18, 'player_id': '736632', 'minutes_played': 28, 'fg': 5, 'fg_a': 9, 'two_pt': 4, 'two_pt_a': 8, 'three_pt': 1, 'three_pt_a': 1, 'ft': 3, 'ft_a': 4, 'o_reb': 4, 'd_reb': 8, 'assist': 1, 'pf': 2, 'stl': 1, 'to': 2, 'blk': 1, 'pts': 14}
# ...
# {'box_score_id': 102, 'player_id': '744670', 'minutes_played': 19, 'fg': 1, 'fg_a': 4, 'two_pt': 1, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 3, 'ft': 2, 'ft_a': 2, 'o_reb': 0, 'd_reb': 3, 'assist': 0, 'pf': 1, 'stl': 1, 'to': 1, 'blk': 0, 'pts': 4}
# {'box_score_id': 102, 'player_id': '736974', 'minutes_played': 18, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 2, 'assist': 1, 'pf': 0, 'stl': 0, 'to': 2, 'blk': 0, 'pts': 0}
# {'box_score_id': 102, 'player_id': '743189', 'minutes_played': 34, 'fg': 5, 'fg_a': 11, 'two_pt': 3, 'two_pt_a': 8, 'three_pt': 2, 'three_pt_a': 3, 'ft': 9, 'ft_a': 10, 'o_reb': 1, 'd_reb': 6, 'assist': 3, 'pf': 0, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 21}
# {'box_score_id': 102, 'player_id': '748565', 'minutes_played': 1, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 102, 'player_id': '744675', 'minutes_played': 1, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 102, 'player_id': '748574', 'minutes_played': 22, 'fg': 3, 'fg_a': 7, 'two_pt': 0, 'two_pt_a': 2, 'three_pt': 3, 'three_pt_a': 5, 'ft': 3, 'ft_a': 3, 'o_reb': 0, 'd_reb': 3, 'assist': 0, 'pf': 2, 'stl': 1, 'to': 1, 'blk': 0, 'pts': 12}
# {'box_score_id': 102, 'player_id': '740397', 'minutes_played': 1, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 102, 'player_id': '744680', 'minutes_played': 1, 'fg': 0, 'fg_a': 1, 'two_pt': 0, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 102, 'player_id': '744682', 'minutes_played': 17, 'fg': 1, 'fg_a': 2, 'two_pt': 1, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 1, 'o_reb': 2, 'd_reb': 2, 'assist': 1, 'pf': 3, 'stl': 1, 'to': 1, 'blk': 0, 'pts': 2}
# {'box_score_id': 102, 'player_id': '744684', 'minutes_played': 26, 'fg': 1, 'fg_a': 4, 'two_pt': 1, 'two_pt_a': 4, 'three_pt': 0, 'three_pt_a': 0, 'ft': 3, 'ft_a': 4, 'o_reb': 2, 'd_reb': 1, 'assist': 3, 'pf': 1, 'stl': 2, 'to': 2, 'blk': 0, 'pts': 5}
# {'box_score_id': 102, 'player_id': '733677', 'minutes_played': 7, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 1, 'pf': 2, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 0}
# {'box_score_id': 103, 'player_id': '744984', 'minutes_played': 21, 'fg': 3, 'fg_a': 6, 'two_pt': 2, 'two_pt_a': 3, 'three_pt': 1, 'three_pt_a': 3, 'ft': 0, 'ft_a': 0, 'o_reb': 2, 'd_reb': 1, 'assist': 0, 'pf': 2, 'stl': 0, 'to': 3, 'blk': 0, 'pts': 7}
# {'box_score_id': 103, 'player_id': '748417', 'minutes_played': 11, 'fg': 1, 'fg_a': 3, 'two_pt': 1, 'two_pt_a': 3, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 0, 'assist': 1, 'pf': 4, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 2}
# {'box_score_id': 103, 'player_id': '744976', 'minutes_played': 26, 'fg': 1, 'fg_a': 6, 'two_pt': 1, 'two_pt_a': 5, 'three_pt': 0, 'three_pt_a': 1, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 1, 'assist': 2, 'pf': 5, 'stl': 1, 'to': 3, 'blk': 0, 'pts': 2}
# {'box_score_id': 103, 'player_id': '738243', 'minutes_played': 26, 'fg': 3, 'fg_a': 4, 'two_pt': 1, 'two_pt_a': 1, 'three_pt': 2, 'three_pt_a': 3, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 7, 'assist': 1, 'pf': 1, 'stl': 1, 'to': 0, 'blk': 1, 'pts': 8}
# {'box_score_id': 103, 'player_id': '748424', 'minutes_played': 29, 'fg': 4, 'fg_a': 10, 'two_pt': 3, 'two_pt_a': 5, 'three_pt': 1, 'three_pt_a': 5, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 0, 'assist': 0, 'pf': 2, 'stl': 0, 'to': 2, 'blk': 0, 'pts': 9}
# {'box_score_id': 103, 'player_id': '748423', 'minutes_played': 14, 'fg': 2, 'fg_a': 3, 'two_pt': 1, 'two_pt_a': 1, 'three_pt': 1, 'three_pt_a': 2, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 2, 'assist': 1, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 5}
# {'box_score_id': 103, 'player_id': '748416', 'minutes_played': 20, 'fg': 3, 'fg_a': 7, 'two_pt': 2, 'two_pt_a': 4, 'three_pt': 1, 'three_pt_a': 3, 'ft': 0, 'ft_a': 1, 'o_reb': 0, 'd_reb': 2, 'assist': 1, 'pf': 2, 'stl': 1, 'to': 2, 'blk': 2, 'pts': 7}
# {'box_score_id': 103, 'player_id': '741237', 'minutes_played': 15, 'fg': 2, 'fg_a': 4, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 2, 'three_pt_a': 4, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 1, 'assist': 2, 'pf': 4, 'stl': 1, 'to': 3, 'blk': 0, 'pts': 6}
# {'box_score_id': 103, 'player_id': '747259', 'minutes_played': 12, 'fg': 1, 'fg_a': 3, 'two_pt': 0, 'two_pt_a': 1, 'three_pt': 1, 'three_pt_a': 2, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 3, 'assist': 2, 'pf': 0, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 3}
# {'box_score_id': 103, 'player_id': '748420', 'minutes_played': 22, 'fg': 3, 'fg_a': 9, 'two_pt': 3, 'two_pt_a': 7, 'three_pt': 0, 'three_pt_a': 2, 'ft': 0, 'ft_a': 3, 'o_reb': 1, 'd_reb': 2, 'assist': 4, 'pf': 1, 'stl': 1, 'to': 0, 'blk': 0, 'pts': 6}
# {'box_score_id': 103, 'player_id': '744987', 'minutes_played': 4, 'fg': 1, 'fg_a': 3, 'two_pt': 1, 'two_pt_a': 3, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 2, 'd_reb': 1, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 2}
# {'box_score_id': 104, 'player_id': '736924', 'minutes_played': 32, 'fg': 7, 'fg_a': 13, 'two_pt': 5, 'two_pt_a': 8, 'three_pt': 2, 'three_pt_a': 5, 'ft': 5, 'ft_a': 7, 'o_reb': 2, 'd_reb': 4, 'assist': 1, 'pf': 1, 'stl': 3, 'to': 1, 'blk': 2, 'pts': 21}
# {'box_score_id': 104, 'player_id': '736927', 'minutes_played': 18, 'fg': 2, 'fg_a': 5, 'two_pt': 2, 'two_pt_a': 4, 'three_pt': 0, 'three_pt_a': 1, 'ft': 2, 'ft_a': 3, 'o_reb': 1, 'd_reb': 2, 'assist': 3, 'pf': 1, 'stl': 2, 'to': 3, 'blk': 0, 'pts': 6}
# {'box_score_id': 104, 'player_id': '745417', 'minutes_played': 16, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 3, 'ft_a': 4, 'o_reb': 1, 'd_reb': 2, 'assist': 2, 'pf': 1, 'stl': 0, 'to': 0, 'blk': 1, 'pts': 3}
# {'box_score_id': 104, 'player_id': '748474', 'minutes_played': 35, 'fg': 8, 'fg_a': 21, 'two_pt': 8, 'two_pt_a': 17, 'three_pt': 0, 'three_pt_a': 4, 'ft': 0, 'ft_a': 2, 'o_reb': 1, 'd_reb': 3, 'assist': 1, 'pf': 1, 'stl': 2, 'to': 3, 'blk': 0, 'pts': 16}
# {'box_score_id': 104, 'player_id': '736925', 'minutes_played': 34, 'fg': 2, 'fg_a': 5, 'two_pt': 1, 'two_pt_a': 2, 'three_pt': 1, 'three_pt_a': 3, 'ft': 2, 'ft_a': 2, 'o_reb': 1, 'd_reb': 2, 'assist': 3, 'pf': 2, 'stl': 0, 'to': 8, 'blk': 0, 'pts': 7}
# {'box_score_id': 104, 'player_id': '748475', 'minutes_played': 15, 'fg': 0, 'fg_a': 1, 'two_pt': 0, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 0, 'ft': 5, 'ft_a': 8, 'o_reb': 1, 'd_reb': 3, 'assist': 0, 'pf': 2, 'stl': 1, 'to': 0, 'blk': 0, 'pts': 5}
# {'box_score_id': 104, 'player_id': '741208', 'minutes_played': 12, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 2, 'assist': 0, 'pf': 4, 'stl': 0, 'to': 0, 'blk': 2, 'pts': 0}
# {'box_score_id': 104, 'player_id': '741257', 'minutes_played': 23, 'fg': 6, 'fg_a': 9, 'two_pt': 2, 'two_pt_a': 4, 'three_pt': 4, 'three_pt_a': 5, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 2, 'assist': 1, 'pf': 2, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 16}
# {'box_score_id': 104, 'player_id': '735475', 'minutes_played': 4, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 1, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 0}
# {'box_score_id': 104, 'player_id': '748478', 'minutes_played': 11, 'fg': 0, 'fg_a': 2, 'two_pt': 0, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 0, 'ft': 2, 'ft_a': 2, 'o_reb': 1, 'd_reb': 0, 'assist': 0, 'pf': 4, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 2}
# {'box_score_id': 105, 'player_id': '740300', 'minutes_played': 30, 'fg': 10, 'fg_a': 17, 'two_pt': 5, 'two_pt_a': 8, 'three_pt': 5, 'three_pt_a': 9, 'ft': 5, 'ft_a': 6, 'o_reb': 1, 'd_reb': 7, 'assist': 2, 'pf': 2, 'stl': 0, 'to': 3, 'blk': 0, 'pts': 30}
# {'box_score_id': 105, 'player_id': '740303', 'minutes_played': 29, 'fg': 1, 'fg_a': 5, 'two_pt': 1, 'two_pt_a': 3, 'three_pt': 0, 'three_pt_a': 2, 'ft': 1, 'ft_a': 2, 'o_reb': 1, 'd_reb': 1, 'assist': 4, 'pf': 2, 'stl': 2, 'to': 2, 'blk': 0, 'pts': 3}
# {'box_score_id': 105, 'player_id': '740298', 'minutes_played': 25, 'fg': 6, 'fg_a': 9, 'two_pt': 6, 'two_pt_a': 9, 'three_pt': 0, 'three_pt_a': 0, 'ft': 6, 'ft_a': 9, 'o_reb': 3, 'd_reb': 4, 'assist': 1, 'pf': 2, 'stl': 0, 'to': 2, 'blk': 1, 'pts': 18}
# {'box_score_id': 105, 'player_id': '740293', 'minutes_played': 33, 'fg': 6, 'fg_a': 6, 'two_pt': 2, 'two_pt_a': 2, 'three_pt': 4, 'three_pt_a': 4, 'ft': 5, 'ft_a': 6, 'o_reb': 0, 'd_reb': 2, 'assist': 8, 'pf': 5, 'stl': 2, 'to': 2, 'blk': 1, 'pts': 21}
# {'box_score_id': 105, 'player_id': '736588', 'minutes_played': 31, 'fg': 1, 'fg_a': 5, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 1, 'three_pt_a': 5, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 2, 'assist': 4, 'pf': 2, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 3}
# {'box_score_id': 105, 'player_id': '748997', 'minutes_played': 19, 'fg': 1, 'fg_a': 6, 'two_pt': 0, 'two_pt_a': 4, 'three_pt': 1, 'three_pt_a': 2, 'ft': 0, 'ft_a': 0, 'o_reb': 2, 'd_reb': 2, 'assist': 1, 'pf': 1, 'stl': 0, 'to': 3, 'blk': 0, 'pts': 3}
# {'box_score_id': 105, 'player_id': '748993', 'minutes_played': 1, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 105, 'player_id': '745494', 'minutes_played': 11, 'fg': 3, 'fg_a': 5, 'two_pt': 2, 'two_pt_a': 2, 'three_pt': 1, 'three_pt_a': 3, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 1, 'assist': 1, 'pf': 4, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 7}
# {'box_score_id': 105, 'player_id': '749003', 'minutes_played': 14, 'fg': 2, 'fg_a': 3, 'two_pt': 2, 'two_pt_a': 3, 'three_pt': 0, 'three_pt_a': 0, 'ft': 1, 'ft_a': 2, 'o_reb': 1, 'd_reb': 3, 'assist': 0, 'pf': 3, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 5}
# {'box_score_id': 105, 'player_id': '745497', 'minutes_played': 6, 'fg': 1, 'fg_a': 4, 'two_pt': 1, 'two_pt_a': 4, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 1, 'd_reb': 4, 'assist': 1, 'pf': 3, 'stl': 0, 'to': 2, 'blk': 1, 'pts': 2}
# {'box_score_id': 105, 'player_id': '745498', 'minutes_played': 1, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 106, 'player_id': '735497', 'minutes_played': 14, 'fg': 8, 'fg_a': 9, 'two_pt': 8, 'two_pt_a': 9, 'three_pt': 0, 'three_pt_a': 0, 'ft': 1, 'ft_a': 3, 'o_reb': 1, 'd_reb': 1, 'assist': 1, 'pf': 2, 'stl': 1, 'to': 0, 'blk': 0, 'pts': 17}
# {'box_score_id': 106, 'player_id': '744757', 'minutes_played': 21, 'fg': 7, 'fg_a': 11, 'two_pt': 5, 'two_pt_a': 5, 'three_pt': 2, 'three_pt_a': 6, 'ft': 2, 'ft_a': 2, 'o_reb': 2, 'd_reb': 4, 'assist': 2, 'pf': 1, 'stl': 1, 'to': 1, 'blk': 3, 'pts': 18}
# {'box_score_id': 106, 'player_id': '736819', 'minutes_played': 24, 'fg': 6, 'fg_a': 8, 'two_pt': 6, 'two_pt_a': 8, 'three_pt': 0, 'three_pt_a': 0, 'ft': 5, 'ft_a': 8, 'o_reb': 6, 'd_reb': 2, 'assist': 2, 'pf': 3, 'stl': 1, 'to': 1, 'blk': 0, 'pts': 17}
# {'box_score_id': 106, 'player_id': '740911', 'minutes_played': 21, 'fg': 0, 'fg_a': 0, 'two_pt': 0, 'two_pt_a': 0, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 2, 'd_reb': 2, 'assist': 6, 'pf': 4, 'stl': 3, 'to': 4, 'blk': 1, 'pts': 0}
# {'box_score_id': 106, 'player_id': '737102', 'minutes_played': 20, 'fg': 7, 'fg_a': 16, 'two_pt': 4, 'two_pt_a': 9, 'three_pt': 3, 'three_pt_a': 7, 'ft': 3, 'ft_a': 4, 'o_reb': 0, 'd_reb': 2, 'assist': 6, 'pf': 0, 'stl': 1, 'to': 1, 'blk': 0, 'pts': 20}
# {'box_score_id': 106, 'player_id': '739545', 'minutes_played': 22, 'fg': 4, 'fg_a': 7, 'two_pt': 4, 'two_pt_a': 7, 'three_pt': 0, 'three_pt_a': 0, 'ft': 1, 'ft_a': 2, 'o_reb': 1, 'd_reb': 4, 'assist': 2, 'pf': 3, 'stl': 3, 'to': 0, 'blk': 1, 'pts': 9}
# {'box_score_id': 106, 'player_id': '744753', 'minutes_played': 11, 'fg': 4, 'fg_a': 5, 'two_pt': 4, 'two_pt_a': 5, 'three_pt': 0, 'three_pt_a': 0, 'ft': 0, 'ft_a': 0, 'o_reb': 4, 'd_reb': 1, 'assist': 1, 'pf': 2, 'stl': 0, 'to': 2, 'blk': 2, 'pts': 8}
# {'box_score_id': 106, 'player_id': '740909', 'minutes_played': 5, 'fg': 0, 'fg_a': 2, 'two_pt': 0, 'two_pt_a': 1, 'three_pt': 0, 'three_pt_a': 1, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 0, 'assist': 0, 'pf': 0, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 0}
# {'box_score_id': 106, 'player_id': '748197', 'minutes_played': 25, 'fg': 2, 'fg_a': 7, 'two_pt': 1, 'two_pt_a': 2, 'three_pt': 1, 'three_pt_a': 5, 'ft': 4, 'ft_a': 4, 'o_reb': 0, 'd_reb': 0, 'assist': 6, 'pf': 0, 'stl': 1, 'to': 2, 'blk': 0, 'pts': 9}
# {'box_score_id': 106, 'player_id': '744755', 'minutes_played': 20, 'fg': 3, 'fg_a': 6, 'two_pt': 2, 'two_pt_a': 2, 'three_pt': 1, 'three_pt_a': 4, 'ft': 1, 'ft_a': 2, 'o_reb': 0, 'd_reb': 6, 'assist': 1, 'pf': 2, 'stl': 0, 'to': 0, 'blk': 0, 'pts': 8}
# {'box_score_id': 106, 'player_id': '748199', 'minutes_played': 17, 'fg': 2, 'fg_a': 3, 'two_pt': 2, 'two_pt_a': 3, 'three_pt': 0, 'three_pt_a': 0, 'ft': 1, 'ft_a': 1, 'o_reb': 2, 'd_reb': 1, 'assist': 2, 'pf': 2, 'stl': 2, 'to': 0, 'blk': 2, 'pts': 5}
# {'box_score_id': 108, 'player_id': '733723', 'minutes_played': 24, 'fg': 7, 'fg_a': 10, 'two_pt': 3, 'two_pt_a': 3, 'three_pt': 4, 'three_pt_a': 7, 'ft': 2, 'ft_a': 2, 'o_reb': 0, 'd_reb': 3, 'assist': 4, 'pf': 3, 'stl': 2, 'to': 2, 'blk': 0, 'pts': 20}
# {'box_score_id': 108, 'player_id': '736360', 'minutes_played': 22, 'fg': 2, 'fg_a': 3, 'two_pt': 2, 'two_pt_a': 3, 'three_pt': 0, 'three_pt_a': 0, 'ft': 3, 'ft_a': 4, 'o_reb': 0, 'd_reb': 2, 'assist': 1, 'pf': 2, 'stl': 1, 'to': 1, 'blk': 0, 'pts': 7}
# {'box_score_id': 108, 'player_id': '737177', 'minutes_played': 22, 'fg': 2, 'fg_a': 7, 'two_pt': 2, 'two_pt_a': 4, 'three_pt': 0, 'three_pt_a': 3, 'ft': 3, 'ft_a': 3, 'o_reb': 1, 'd_reb': 4, 'assist': 2, 'pf': 4, 'stl': 0, 'to': 2, 'blk': 0, 'pts': 7}
# {'box_score_id': 108, 'player_id': '736359', 'minutes_played': 22, 'fg': 2, 'fg_a': 13, 'two_pt': 1, 'two_pt_a': 6, 'three_pt': 1, 'three_pt_a': 7, 'ft': 5, 'ft_a': 6, 'o_reb': 1, 'd_reb': 4, 'assist': 3, 'pf': 1, 'stl': 0, 'to': 1, 'blk': 0, 'pts': 10}
# {'box_score_id': 108, 'player_id': '736362', 'minutes_played': 20, 'fg': 2, 'fg_a': 3, 'two_pt': 2, 'two_pt_a': 2, 'three_pt': 0, 'three_pt_a': 1, 'ft': 2, 'ft_a': 2, 'o_reb': 1, 'd_reb': 6, 'assist': 4, 'pf': 4, 'stl': 1, 'to': 0, 'blk': 0, 'pts': 6}
# {'box_score_id': 108, 'player_id': '744153', 'minutes_played': 16, 'fg': 4, 'fg_a': 5, 'two_pt': 4, 'two_pt_a': 5, 'three_pt': 0, 'three_pt_a': 0, 'ft': 3, 'ft_a': 3, 'o_reb': 4, 'd_reb': 2, 'assist': 1, 'pf': 2, 'stl': 1, 'to': 0, 'blk': 1, 'pts': 11}
# {'box_score_id': 108, 'player_id': '744152', 'minutes_played': 19, 'fg': 3, 'fg_a': 7, 'two_pt': 2, 'two_pt_a': 3, 'three_pt': 1, 'three_pt_a': 4, 'ft': 0, 'ft_a': 0, 'o_reb': 2, 'd_reb': 1, 'assist': 2, 'pf': 2, 'stl': 3, 'to': 1, 'blk': 0, 'pts': 7}
# {'box_score_id': 108, 'player_id': '744151', 'minutes_played': 11, 'fg': 2, 'fg_a': 6, 'two_pt': 2, 'two_pt_a': 6, 'three_pt': 0, 'three_pt_a': 0, 'ft': 1, 'ft_a': 2, 'o_reb': 2, 'd_reb': 0, 'assist': 0, 'pf': 4, 'stl': 0, 'to': 0, 'blk': 1, 'pts': 5}
# {'box_score_id': 108, 'player_id': '747630', 'minutes_played': 22, 'fg': 4, 'fg_a': 4, 'two_pt': 3, 'two_pt_a': 3, 'three_pt': 1, 'three_pt_a': 1, 'ft': 0, 'ft_a': 0, 'o_reb': 0, 'd_reb': 3, 'assist': 3, 'pf': 1, 'stl': 0, 'to': 2, 'blk': 0, 'pts': 9}
